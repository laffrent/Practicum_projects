# %% [markdown]
# <h1> Комментарий тимлида </h1>
#
# 👋 **Приветствую, Евгений!**
#
# ✨ Поздравляю с началом работы над финальным проектом!
#
# Меня зовут Арсен Абдулин и я буду твоим ревьювером. Помню, однажды проверял твой проект =)
#
# При проверке работ я пишу следующие комментарии:
#
# <div class="alert alert-success">
# <b>✔️ Зеленым цветом</b> отмечены удачные решения.</div>
#
# <div class="alert alert-warning">
# <b>⚠️ Желтым цветом</b> я отметил пункты, которые в следующий раз можно сделать по-другому. Одно-два таких замечания в проекте допускается, но если их много — проект следует доработать. </div>
#
# <div class="alert alert-danger">
# <b>🚫 Красным цветом</b> отмечены критические замечания, которые необходимо поправить, чтобы принять проект. </div>
#
# Если какие-то моменты в задании для тебя были непонятны и у тебя есть ко мне вопросы — смело спрашивай 😊 Также ты можешь доработать места, где есть желтые комментарии в проекте (однако, это не обязательно).
#
# Предлагаю работать в диалоге: если ты решишь что-то поменять по моим рекомендациям — пиши об этом (выбери для своих комментариев определенный цвет - так мне будет легче увидеть изменения). Пожалуйста не перемещай, не изменяй и не удаляй мои комментарии. Все это поможет сделать проверку твоего проекта оперативнее.
#
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Пример комментария. </div>

# %% [markdown]
# Вопросов, пока особо нет

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Принято!
#
# </div>

# %% [markdown]
# # Отток клиентов телеком компании

# %% [markdown]
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Хорошо, когда есть описание проекта и обозначения признаков — так гораздо проще ознакомиться!
#
# </div>

# %% [markdown]
# ### Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL, от англ. digital subscriber line, «цифровая абонентская линия») или оптоволоконный кабель (Fiber optic).
#
# Также доступны такие услуги:
# - Интернет-безопасность: антивирус (DeviceProtection) и блокировка небезопасных сайтов (OnlineSecurity);
# - Выделенная линия технической поддержки (TechSupport);
# - Облачное хранилище файлов для резервного копирования данных (OnlineBackup);
# - Стриминговое телевидение (StreamingTV) и каталог фильмов (StreamingMovies).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.
#
# ###  Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
# * `contract.csv` — информация о договоре;
# * `personal.csv` — персональные данные клиента;
# * `internet.csv` — информация об интернет-услугах;
# * `phone.csv` — информация об услугах телефонии.
#
# В данных предоставлены следующие признаки:
# + BeginDate – дата начала пользования услугами,
# + EndDate – дата окончания пользования услугами,
# + Type – тип оплаты: ежемесячный, годовой и тд,
# + PaperlessBilling – безналичный расчет,
# + PaymentMethod – способ оплаты,
# + MonthlyCharges – ежемесячные траты на услуги,
# + TotalCharges – всего потрачено денег на услуги
# + Dependents – наличие иждивенцев
# + Senior Citizen – наличие пенсионного статуса по возрасту
# + Partner – наличие супруга(и)
# + MultipleLines – наличие возможности ведения параллельных линий во время
# звонка
#
#
# Во всех файлах столбец customerID содержит код клиента.
# Информация о договорах актуальна на 1 февраля 2020.
#
# ### План работы
# 1. Загрузка и ознакомление с данными
#     + загрузка необходимых библиотек
#     + загрузка данных
#     + ознакомление и обозначение проблем для этапа предобработки
# 2. Предварительная обработка данных
#     + объединение данных
#     + обработка пропусков
#     + преобразование типов
#     + добавление новых признаков
# 3. Исследовательский анализ
#     + проверка распределений данных
#     + проверка зависимостей целевой переменной
#     + формирование и проверка гипотез
# 4. Подготовка и обучение модели
#     + разбиение данных на тренировочную и тестовую выборки
#     + создание несколько моделей (pipeline c CV)
#     + обучение и определение лучшей модели
# 5. Проверка работы модели
#     + проверка на тестовой выборке
#     + анализ результатов работы модели
# 6. Вывод
#     + вывод
#     + параметры финальной модели
#
# ### Критерии оценки работы
#
# Основная метрика: **AUC-ROC**\
# Дополнительная метрика: **Accuracy**\
# Критерии оценки: **AUC-ROC >= 0.85**

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> План работ последовательный и понятный, замечаний нет!
#
# </div>

# %% [markdown]
# ## Загрузка и ознакомление с данными

# %% [markdown]
# Загрузим необходимые библиотеки

# %%
# %pip install phik
# Out:
# Requirement already satisfied: phik in c:\users\s7\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\s7\anaconda3\lib\site-packages (from phik) (3.4.3)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\s7\anaconda3\lib\site-packages (from phik) (1.3.4)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\s7\anaconda3\lib\site-packages (from phik) (1.2.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\s7\anaconda3\lib\site-packages (from phik) (1.22.4)
# Requirement already satisfied: scipy>=1.5.2 in c:\users\s7\anaconda3\lib\site-packages (from phik) (1.7.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\s7\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\s7\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\s7\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\s7\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\s7\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (0.10.0)
# Requirement already satisfied: six in c:\users\s7\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2.3->phik) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\s7\anaconda3\lib\site-packages (from pandas>=0.25.1->phik) (2021.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
from IPython.display import display

import matplotlib.pyplot as plt
import numpy as np
import phik
#from phik.report import plot_correlation_matrix
#from phik import report
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.utils import shuffle # Миксер
from sklearn.utils.validation import check_is_fitted

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.feature_extraction import FeatureHasher

from catboost import CatBoostClassifier

# %% [markdown]
# Зафиксируем глобальные переменные

# %%
MY_DIR = 'data/'
YA_DIR = '/datasets/final_provider/'
RANDOM_STATE = 270223

# %% [markdown]
# Считаем данные

# %%
def search_and_var_naming(dir):
    """
    Search all *.csv files in dir and creat dic varname:filepath
    dir -- directory with data
    sep -- win/lin filepath sep
    """
    csv_files = {}
    for root, dirs, files in os.walk(dir):
        counter = 0
        for file in files:
            if file.endswith(".csv"):
                counter += 1
                csv_files[file.split('.')[0]] = dir + file
        if counter == 0:
            print('В папке отсутствуют файлы формата *.csv')
        else:
            print(f'Количество найденных файлов *.csv: {counter}')
    return csv_files

# %%
if os.path.exists(MY_DIR):
    print('Используется локальная папка')
    files_and_path = search_and_var_naming(MY_DIR)
elif os.path.exists(YA_DIR):
    print('Используется репозиторий Yandex')    
    files_and_path = search_and_var_naming(YA_DIR)
else:
    print('Папка с данными не найдена')
# Out:
# Используется локальная папка
# Количество найденных файлов *.csv: 4

# %% [markdown]
# Преобразуем и присвоим найденным файлам имена в соответствии с их названием

# %%
for key in files_and_path:
    exec(f'{key} = pd.read_csv(files_and_path[key])')
    print(key)
# Out:
# contract
# internet
# personal
# phone

# %%
files = [contract, internet, personal, phone]

# %% [markdown]
# Преобразуем имена колонок в snake_case

# %%
for file in files:
    new_columns_name=[]
    for column in file.columns:
        new_columns_name.append(re.sub('(?!^)([A-Z]+)', r'_\1', column).lower())
    file.columns = new_columns_name

# %% [markdown]
# ### Последовательно изучим общую информацию о всех представленных данных

# %% [markdown]
# #### contract

# %%
def base_info(df:pd.DataFrame):
    """
    Display some base info about df
    head, tail, info, describe
    """
    print('Head')
    display(df.head())
    print('*'*120)
    print('Tail')
    display(df.tail())
    print('*'*120)   
    print('Info')
    df.info()
    print('*'*120)
    print('Describe')
    display(df.describe(include='all'))

# %%
base_info(contract)
# Out:
# Head
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperless_billing             payment_method  monthly_charges total_charges
# 0               Yes           Electronic check            29.85         29.85
# 1                No               Mailed check            56.95        1889.5
# 2               Yes               Mailed check            53.85        108.15
# 3                No  Bank transfer (automatic)            42.30       1840.75
# 4               Yes           Electronic check            70.70        151.65
# ************************************************************************************************************************
# Tail
#      customer_id  begin_date             end_date            type  \
# 7038  6840-RESVB  2018-02-01                   No        One year
# 7039  2234-XADUH  2014-02-01                   No        One year
# 7040  4801-JZAZL  2019-03-01                   No  Month-to-month
# 7041  8361-LTMKD  2019-07-01  2019-11-01 00:00:00  Month-to-month
# 7042  3186-AJIEK  2014-08-01                   No        Two year
#
#      paperless_billing             payment_method  monthly_charges  \
# 7038               Yes               Mailed check            84.80
# 7039               Yes    Credit card (automatic)           103.20
# 7040               Yes           Electronic check            29.60
# 7041               Yes               Mailed check            74.40
# 7042               Yes  Bank transfer (automatic)           105.65
#
#      total_charges
# 7038        1990.5
# 7039        7362.9
# 7040        346.45
# 7041         306.6
# 7042        6844.5
# ************************************************************************************************************************
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
# ************************************************************************************************************************
# Describe
#        customer_id  begin_date end_date            type paperless_billing  \
# count         7043        7043     7043            7043              7043
# unique        7043          77        5               3                 2
# top     7590-VHVEG  2014-02-01       No  Month-to-month               Yes
# freq             1         366     5174            3875              4171
# mean           NaN         NaN      NaN             NaN               NaN
# std            NaN         NaN      NaN             NaN               NaN
# min            NaN         NaN      NaN             NaN               NaN
# 25%            NaN         NaN      NaN             NaN               NaN
# 50%            NaN         NaN      NaN             NaN               NaN
# 75%            NaN         NaN      NaN             NaN               NaN
# max            NaN         NaN      NaN             NaN               NaN
#
#           payment_method  monthly_charges total_charges
# count               7043      7043.000000          7043
# unique                 4              NaN          6531
# top     Electronic check              NaN
# freq                2365              NaN            11
# mean                 NaN        64.761692           NaN
# std                  NaN        30.090047           NaN
# min                  NaN        18.250000           NaN
# 25%                  NaN        35.500000           NaN
# 50%                  NaN        70.350000           NaN
# 75%                  NaN        89.850000           NaN
# max                  NaN       118.750000           NaN

# %% [markdown]
# Явные пропуски отсутствуют.
# + `begin_date` - необходимо будет преобразовать в формат даты и при анализе проверить утверждение, чем более долгий срок клиент с компанией тем меньшая вероятность его ухода
# + `end_date` - целевой признак, если клиент ушел дата будет обозначена также необходимо преобразовать в формат даты, и преобразовать с `begin_date` в срок обслуживания
# + `total_charges` - проверим на пропуски и преобразуем в числовой
# + `monthly_charges` - тип данных ожидаемый, проверим если средний чек совпадает 'кол-во месяцев' / `total_charges` == `monthly_charges`, то клиент не увеличивал кол-во услуг, меньше -> отказывался, больше -> добавлял

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Данные загружены успешно! Хорошо, что сделал подробный анализ данных, видно что нужна дальнейшая предобработка
#
# </div>

# %% [markdown]
# Количество уникальных ID совпадает с количеством строк, следовательно полные дубликаты отсутствуют. Попробывать разбить преобразовать в хэш текстовую часть а цифровую посмотреть может в ней регион, офис и т.д, может быть корреляция с датой то удалим

# %%
contract.paperless_billing.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# `paperless_billing` - уникальные значения да/нет

# %%
contract.payment_method.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %% [markdown]
# `payment_method` варианты платежей, проверим на зависимость с `paperless_billing` и на возможность объединения по методу платежа check/automatic

# %%
contract.type.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# `type` - тип платежа, логично будет преположить что чем на более длительный срок клиент оплачивает услуги тем меньше вероятность его ухода, проверим при анализе данных

# %% [markdown]
# #### internet

# %%
base_info(internet)
# Out:
# Head
#   customer_id internet_service online_security online_backup  \
# 0  7590-VHVEG              DSL              No           Yes
# 1  5575-GNVDE              DSL             Yes            No
# 2  3668-QPYBK              DSL             Yes           Yes
# 3  7795-CFOCW              DSL             Yes            No
# 4  9237-HQITU      Fiber optic              No            No
#
#   device_protection tech_support streaming_tv streaming_movies
# 0                No           No           No               No
# 1               Yes           No           No               No
# 2                No           No           No               No
# 3               Yes          Yes           No               No
# 4                No           No           No               No
# ************************************************************************************************************************
# Tail
#      customer_id internet_service online_security online_backup  \
# 5512  6840-RESVB              DSL             Yes            No
# 5513  2234-XADUH      Fiber optic              No           Yes
# 5514  4801-JZAZL              DSL             Yes            No
# 5515  8361-LTMKD      Fiber optic              No            No
# 5516  3186-AJIEK      Fiber optic             Yes            No
#
#      device_protection tech_support streaming_tv streaming_movies
# 5512               Yes          Yes          Yes              Yes
# 5513               Yes           No          Yes              Yes
# 5514                No           No           No               No
# 5515                No           No           No               No
# 5516               Yes          Yes          Yes              Yes
# ************************************************************************************************************************
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        5517 non-null   object
#  1   internet_service   5517 non-null   object
#  2   online_security    5517 non-null   object
#  3   online_backup      5517 non-null   object
#  4   device_protection  5517 non-null   object
#  5   tech_support       5517 non-null   object
#  6   streaming_tv       5517 non-null   object
#  7   streaming_movies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
# ************************************************************************************************************************
# Describe
#        customer_id internet_service online_security online_backup  \
# count         5517             5517            5517          5517
# unique        5517                2               2             2
# top     7590-VHVEG      Fiber optic              No            No
# freq             1             3096            3498          3088
#
#        device_protection tech_support streaming_tv streaming_movies
# count               5517         5517         5517             5517
# unique                 2            2            2                2
# top                   No           No           No               No
# freq                3095         3473         2810             2785

# %%
internet.internet_service.unique()
# Out:
# array(['DSL', 'Fiber optic'], dtype=object)

# %% [markdown]
# Значений меньше чем в `contract` - не все пользователи пользуются услугой интернет. В столбце internet_service два вида подключения. В остальных подключена ли услуга да/нет
# Преобразование типов не требуется

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Все верно, не все клиенты пользуются интернет-услугами
#
# </div>

# %% [markdown]
# Сделаем проверку для будущего объеденения

# %%
len(internet[~internet['customer_id'].isin(contract['customer_id'])])
# Out:
# 0

# %% [markdown]
# #### personal

# %%
base_info(personal)
# Out:
# Head
#   customer_id  gender  senior_citizen partner dependents
# 0  7590-VHVEG  Female               0     Yes         No
# 1  5575-GNVDE    Male               0      No         No
# 2  3668-QPYBK    Male               0      No         No
# 3  7795-CFOCW    Male               0      No         No
# 4  9237-HQITU  Female               0      No         No
# ************************************************************************************************************************
# Tail
#      customer_id  gender  senior_citizen partner dependents
# 7038  6840-RESVB    Male               0     Yes        Yes
# 7039  2234-XADUH  Female               0     Yes        Yes
# 7040  4801-JZAZL  Female               0     Yes        Yes
# 7041  8361-LTMKD    Male               1     Yes         No
# 7042  3186-AJIEK    Male               0      No         No
# ************************************************************************************************************************
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     7043 non-null   object
#  1   gender          7043 non-null   object
#  2   senior_citizen  7043 non-null   int64
#  3   partner         7043 non-null   object
#  4   dependents      7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# ************************************************************************************************************************
# Describe
#        customer_id gender  senior_citizen partner dependents
# count         7043   7043     7043.000000    7043       7043
# unique        7043      2             NaN       2          2
# top     7590-VHVEG   Male             NaN      No         No
# freq             1   3555             NaN    3641       4933
# mean           NaN    NaN        0.162147     NaN        NaN
# std            NaN    NaN        0.368612     NaN        NaN
# min            NaN    NaN        0.000000     NaN        NaN
# 25%            NaN    NaN        0.000000     NaN        NaN
# 50%            NaN    NaN        0.000000     NaN        NaN
# 75%            NaN    NaN        0.000000     NaN        NaN
# max            NaN    NaN        1.000000     NaN        NaN

# %%
personal.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
personal.senior_citizen.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Значения в остальных столбцах да/нет

# %% [markdown]
# Проверка

# %%
len(personal[~personal['customer_id'].isin(contract['customer_id'])])
# Out:
# 0

# %% [markdown]
# #### phone

# %%
base_info(phone)
# Out:
# Head
#   customer_id multiple_lines
# 0  5575-GNVDE             No
# 1  3668-QPYBK             No
# 2  9237-HQITU             No
# 3  9305-CDSKC            Yes
# 4  1452-KIOVK            Yes
# ************************************************************************************************************************
# Tail
#      customer_id multiple_lines
# 6356  2569-WGERO             No
# 6357  6840-RESVB            Yes
# 6358  2234-XADUH            Yes
# 6359  8361-LTMKD            Yes
# 6360  3186-AJIEK             No
# ************************************************************************************************************************
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     6361 non-null   object
#  1   multiple_lines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# ************************************************************************************************************************
# Describe
#        customer_id multiple_lines
# count         6361           6361
# unique        6361              2
# top     5575-GNVDE             No
# freq             1           3390

# %% [markdown]
# phone - содержит информацию о пользователях телефоном и подключена ли услуга нескольких линий

# %%
len(phone[~phone['customer_id'].isin(contract['customer_id'])])
# Out:
# 0

# %% [markdown]
# ### Вывод:

# %% [markdown]
# В данном разделе мы провели загрузку и предварительное ознакомление с данными. Данные представлены в виде 4х файлов формата *.csv.
# Переименовали столбцы в более удобный формат для работы. Датафреймам присвоили имена соответственно именам файлов из которых загружали
#
# `contract` Данные предоставлены с 2014-02-01 по . 7043 строки  по 8 признаков. Пропуски и дубликаты не найдены. Обнаружены несоответствия типов данных. Из двух столбцов даты начала контракта и его окончания необходимо будет сформировать длительность пользования услугами, и выделить целевую переменную - факт окончания контракта.
#
# `internet` 5517 клиентов с 8-ю признаками. Преобразования не требуются.
#
# `personal` 7043 строки с 5-ю признаками. Признак `senior_citizen` кодирован 1/0 вместо обычного yes/no
#
# `phone` 6361 строка с 2-я признаками
#
# Во всех таблица первичным ключом является `customer_id` по нему будем производить объединение таблиц.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Все хорошо, данные готовы для объединения таблиц!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> План работ принят, можно приступать к основному проекту.
#
# Пожалуйста сохрани наши с тобой комментарии, а проект продолжай делать в этом же документе, успехов!
#
# </div>

# %% [markdown]
# ## Предварительная обработка данных

# %% [markdown]
# Сведем все данные в единый датафрейм

# %% [markdown]
# Перед сведение добавим индикаторные столбцы наличия услуг интернет и телефона

# %%
internet['internet_service'] = 'Yes'
phone['phone_service'] = 'Yes'

# %%
df = contract.merge(personal, how='left', on='customer_id')
df = df.merge(internet, how='left', on='customer_id')
df = df.merge(phone, how='left', on='customer_id')

# %%
pd.DataFrame({'NaNs, %': round((df.isna().mean()*100),2), 
              'NaNs, qty': df.isna().sum()}).style.format('{:.2f}').background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_915b2_row0_col0, #T_915b2_row0_col1, #T_915b2_row1_col0, #T_915b2_row1_col1, #T_915b2_row2_col0, #T_915b2_row2_col1, #T_915b2_row3_col0, #T_915b2_row3_col1, #T_915b2_row4_col0, #T_915b2_row4_col1, #T_915b2_row5_col0, #T_915b2_row5_col1, #T_915b2_row6_col0, #T_915b2_row6_col1, #T_915b2_row7_col0, #T_915b2_row7_col1, #T_915b2_row8_col0, #T_915b2_row8_col1, #T_915b2_row9_col0, #T_915b2_row9_col1, #T_915b2_row10_col0, #T_915b2_row10_col1, #T_915b2_row11_col0, #T_915b2_row11_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_915b2_row12_col0, #T_915b2_row12_col1, #T_915b2_row13_col0, #T_915b2_row13_col1, #T_915b2_row14_col0, #T_915b2_row14_col1, #T_915b2_row15_col0, #T_915b2_row15_col1, #T_915b2_row16_col0, #T_915b2_row16_col1, #T_915b2_row17_col0, #T_915b2_row17_col1, #T_915b2_row18_col0, #T_915b2_row18_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_915b2_row19_col0, #T_915b2_row19_col1, #T_915b2_row20_col0, #T_915b2_row20_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# </style>
# <table id="T_915b2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NaNs, %</th>
#       <th class="col_heading level0 col1" >NaNs, qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_915b2_level0_row0" class="row_heading level0 row0" >customer_id</th>
#       <td id="T_915b2_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_915b2_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row1" class="row_heading level0 row1" >begin_date</th>
#       <td id="T_915b2_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_915b2_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row2" class="row_heading level0 row2" >end_date</th>
#       <td id="T_915b2_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_915b2_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row3" class="row_heading level0 row3" >type</th>
#       <td id="T_915b2_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_915b2_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row4" class="row_heading level0 row4" >paperless_billing</th>
#       <td id="T_915b2_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_915b2_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row5" class="row_heading level0 row5" >payment_method</th>
#       <td id="T_915b2_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_915b2_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row6" class="row_heading level0 row6" >monthly_charges</th>
#       <td id="T_915b2_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_915b2_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row7" class="row_heading level0 row7" >total_charges</th>
#       <td id="T_915b2_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_915b2_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row8" class="row_heading level0 row8" >gender</th>
#       <td id="T_915b2_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_915b2_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row9" class="row_heading level0 row9" >senior_citizen</th>
#       <td id="T_915b2_row9_col0" class="data row9 col0" >0.00</td>
#       <td id="T_915b2_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row10" class="row_heading level0 row10" >partner</th>
#       <td id="T_915b2_row10_col0" class="data row10 col0" >0.00</td>
#       <td id="T_915b2_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row11" class="row_heading level0 row11" >dependents</th>
#       <td id="T_915b2_row11_col0" class="data row11 col0" >0.00</td>
#       <td id="T_915b2_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row12" class="row_heading level0 row12" >internet_service</th>
#       <td id="T_915b2_row12_col0" class="data row12 col0" >21.67</td>
#       <td id="T_915b2_row12_col1" class="data row12 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row13" class="row_heading level0 row13" >online_security</th>
#       <td id="T_915b2_row13_col0" class="data row13 col0" >21.67</td>
#       <td id="T_915b2_row13_col1" class="data row13 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row14" class="row_heading level0 row14" >online_backup</th>
#       <td id="T_915b2_row14_col0" class="data row14 col0" >21.67</td>
#       <td id="T_915b2_row14_col1" class="data row14 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row15" class="row_heading level0 row15" >device_protection</th>
#       <td id="T_915b2_row15_col0" class="data row15 col0" >21.67</td>
#       <td id="T_915b2_row15_col1" class="data row15 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row16" class="row_heading level0 row16" >tech_support</th>
#       <td id="T_915b2_row16_col0" class="data row16 col0" >21.67</td>
#       <td id="T_915b2_row16_col1" class="data row16 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row17" class="row_heading level0 row17" >streaming_tv</th>
#       <td id="T_915b2_row17_col0" class="data row17 col0" >21.67</td>
#       <td id="T_915b2_row17_col1" class="data row17 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row18" class="row_heading level0 row18" >streaming_movies</th>
#       <td id="T_915b2_row18_col0" class="data row18 col0" >21.67</td>
#       <td id="T_915b2_row18_col1" class="data row18 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row19" class="row_heading level0 row19" >multiple_lines</th>
#       <td id="T_915b2_row19_col0" class="data row19 col0" >9.68</td>
#       <td id="T_915b2_row19_col1" class="data row19 col1" >682.00</td>
#     </tr>
#     <tr>
#       <th id="T_915b2_level0_row20" class="row_heading level0 row20" >phone_service</th>
#       <td id="T_915b2_row20_col0" class="data row20 col0" >9.68</td>
#       <td id="T_915b2_row20_col1" class="data row20 col1" >682.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Пропуски образовались при соединении таблиц заменим на 'No'

# %%
df = df.fillna('No')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   object
#  8   gender             7043 non-null   object
#  9   senior_citizen     7043 non-null   int64
#  10  partner            7043 non-null   object
#  11  dependents         7043 non-null   object
#  12  internet_service   7043 non-null   object
#  13  online_security    7043 non-null   object
#  14  online_backup      7043 non-null   object
#  15  device_protection  7043 non-null   object
#  16  tech_support       7043 non-null   object
#  17  streaming_tv       7043 non-null   object
#  18  streaming_movies   7043 non-null   object
#  19  multiple_lines     7043 non-null   object
#  20  phone_service      7043 non-null   object
# dtypes: float64(1), int64(1), object(19)
# memory usage: 1.2+ MB

# %% [markdown]
# Преобрзуем в формат даты времени

# %%
df['begin_date'] = pd.to_datetime(df['begin_date'])

# %% [markdown]
# При предварительном исследовании нам попадались даты с днем равным 1 проверим, если так следовательно данные представлены с разбивкой по месяцам

# %%
df['begin_date'].dt.day.unique()
# Out:
# array([1], dtype=int64)

# %%
df['end_date'].unique()
# Out:
# array(['No', '2019-12-01 00:00:00', '2019-11-01 00:00:00',
#        '2019-10-01 00:00:00', '2020-01-01 00:00:00'], dtype=object)

# %% [markdown]
# Клиенты начали уходить с 2019-10-01. Странно что до этого за такой долгий срок работы из компании не ушел ни один клиент, а потом резко начали

# %% [markdown]
# Создадим нашу целевую переменную

# %%
df['target'] = np.where((df['end_date'] != 'No'), 1, 0)

# %%
df['end_date'] = pd.to_datetime(df['end_date'], errors ='coerce')
df['end_date'].max()
# Out:
# Timestamp('2020-01-01 00:00:00')

# %% [markdown]
# Максимальная дата растожения контракта отличается от даты выгрузки `2020-02-01`, поэтому можем заменить все `NaT` на нее. При исследовании данных будем учитывать данную замену

# %%
df['end_date'] = df['end_date'].fillna(pd.Timestamp('2020-02-01'))

# %%
df['end_date'].unique()
# Out:
# array(['2020-02-01T00:00:00.000000000', '2019-12-01T00:00:00.000000000',
#        '2019-11-01T00:00:00.000000000', '2019-10-01T00:00:00.000000000',
#        '2020-01-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# Теперь добавим столбец с длительностью контракта до момента расторжения или если клиент не ушел на дату выгрузки

# %%
df['term'] = (df['end_date'].dt.to_period('M') - df['begin_date'].dt.to_period('M')).apply(lambda x: x.n)

# %%
df.head()
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month               Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year                No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month               Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year                No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges total_charges  gender  \
# 0           Electronic check            29.85         29.85  Female
# 1               Mailed check            56.95        1889.5    Male
# 2               Mailed check            53.85        108.15    Male
# 3  Bank transfer (automatic)            42.30       1840.75    Male
# 4           Electronic check            70.70        151.65  Female
#
#    senior_citizen  ... online_security online_backup device_protection  \
# 0               0  ...              No           Yes                No
# 1               0  ...             Yes            No               Yes
# 2               0  ...             Yes           Yes                No
# 3               0  ...             Yes            No               Yes
# 4               0  ...              No            No                No
#
#   tech_support streaming_tv streaming_movies multiple_lines phone_service  \
# 0           No           No               No             No            No
# 1           No           No               No             No           Yes
# 2           No           No               No             No           Yes
# 3          Yes           No               No             No            No
# 4           No           No               No             No           Yes
#
#   target term
# 0      0    1
# 1      0   34
# 2      1    2
# 3      0   45
# 4      1    2
#
# [5 rows x 23 columns]

# %%
df.total_charges.sort_values().head(15)
# Out:
# 936
# 3826
# 4380
# 753
# 5218
# 3331
# 6754
# 6670
# 1340
# 488
# 1082
# 105      100.2
# 4459    100.25
# 1723    100.35
# 2124     100.4
# Name: total_charges, dtype: object

# %% [markdown]
# В столбце `total_charges` пропуски заполнены пробелами, проверим когда пришли эти клиенты

# %%
df.query('total_charges == " "')['begin_date'].unique()
# Out:
# array(['2020-02-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# Все клиенты пришли 2020-02-01 и не пользовались еще услугами, поэтому у них еще нет `total_charges`. И не известно уйдут они или останутся. Преобразуем столбец и удалим их

# %%
df['total_charges'] = pd.to_numeric(df['total_charges'], errors ='coerce').sort_values()
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7032 non-null   object
#  1   begin_date         7032 non-null   datetime64[ns]
#  2   end_date           7032 non-null   datetime64[ns]
#  3   type               7032 non-null   object
#  4   paperless_billing  7032 non-null   object
#  5   payment_method     7032 non-null   object
#  6   monthly_charges    7032 non-null   float64
#  7   total_charges      7032 non-null   float64
#  8   gender             7032 non-null   object
#  9   senior_citizen     7032 non-null   int64
#  10  partner            7032 non-null   object
#  11  dependents         7032 non-null   object
#  12  internet_service   7032 non-null   object
#  13  online_security    7032 non-null   object
#  14  online_backup      7032 non-null   object
#  15  device_protection  7032 non-null   object
#  16  tech_support       7032 non-null   object
#  17  streaming_tv       7032 non-null   object
#  18  streaming_movies   7032 non-null   object
#  19  multiple_lines     7032 non-null   object
#  20  phone_service      7032 non-null   object
#  21  target             7032 non-null   int32
#  22  term               7032 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int32(1), int64(2), object(16)
# memory usage: 1.3+ MB

# %% [markdown]
# Разделим ID на текстовую и числовую часть

# %%
df[['num_id', 'text_id']] = df['customer_id'].str.split('-', 1, expand= True)
df['num_id'] = df['num_id'].astype(int)

# %% [markdown]
# Добавим также столбец с разницей

# %%
# def reduce_increase(month, total, term):
#     if (total/term) > month:
#         return 1
#     elif (total/term) < month:
#         return -1
#     else:
#         return 0

# %%
# df['reduce_increase_services'] = df.apply(lambda df: reduce_increase(
#     df['monthly_charges'], 
#     df['total_charges'], 
#     df['term']), axis=1)

# %%
df['reduce_increase_services'] = (((df['total_charges']/ df['term']) - df['monthly_charges']) / df['monthly_charges'])

# %%
df.head()
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month               Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year                No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month               Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year                No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges  gender  \
# 0           Electronic check            29.85          29.85  Female
# 1               Mailed check            56.95        1889.50    Male
# 2               Mailed check            53.85         108.15    Male
# 3  Bank transfer (automatic)            42.30        1840.75    Male
# 4           Electronic check            70.70         151.65  Female
#
#    senior_citizen  ... tech_support streaming_tv streaming_movies  \
# 0               0  ...           No           No               No
# 1               0  ...           No           No               No
# 2               0  ...           No           No               No
# 3               0  ...          Yes           No               No
# 4               0  ...           No           No               No
#
#   multiple_lines phone_service target term num_id text_id  \
# 0             No            No      0    1   7590   VHVEG
# 1             No           Yes      0   34   5575   GNVDE
# 2             No           Yes      1    2   3668   QPYBK
# 3             No            No      0   45   7795   CFOCW
# 4             No           Yes      1    2   9237   HQITU
#
#   reduce_increase_services
# 0                 0.000000
# 1                -0.024170
# 2                 0.004178
# 3                -0.032966
# 4                 0.072489
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               7032 non-null   object
#  1   begin_date                7032 non-null   datetime64[ns]
#  2   end_date                  7032 non-null   datetime64[ns]
#  3   type                      7032 non-null   object
#  4   paperless_billing         7032 non-null   object
#  5   payment_method            7032 non-null   object
#  6   monthly_charges           7032 non-null   float64
#  7   total_charges             7032 non-null   float64
#  8   gender                    7032 non-null   object
#  9   senior_citizen            7032 non-null   int64
#  10  partner                   7032 non-null   object
#  11  dependents                7032 non-null   object
#  12  internet_service          7032 non-null   object
#  13  online_security           7032 non-null   object
#  14  online_backup             7032 non-null   object
#  15  device_protection         7032 non-null   object
#  16  tech_support              7032 non-null   object
#  17  streaming_tv              7032 non-null   object
#  18  streaming_movies          7032 non-null   object
#  19  multiple_lines            7032 non-null   object
#  20  phone_service             7032 non-null   object
#  21  target                    7032 non-null   int32
#  22  term                      7032 non-null   int64
#  23  num_id                    7032 non-null   int32
#  24  text_id                   7032 non-null   object
#  25  reduce_increase_services  7032 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int32(2), int64(2), object(17)
# memory usage: 1.4+ MB

# %%
df.groupby('begin_date')['customer_id'].count()
# Out:
# begin_date
# 2013-10-01      3
# 2013-11-01      2
# 2013-12-01      3
# 2014-01-01      7
# 2014-02-01    366
#              ...
# 2019-09-01    237
# 2019-10-01    237
# 2019-11-01    237
# 2019-12-01    220
# 2020-01-01    233
# Name: customer_id, Length: 76, dtype: int64

# %% [markdown]
# ### Вывод:

# %% [markdown]
# На этапе предварительной обработки мы объеденили все таблицы в одну по ключу `customer_id`. Пропуски заполним yes/no. При этом, так как, не все пользователи пользуются услугами интеренета или телефона создадим два столбца с информацией об услугах.
#
# Преобразовали даты в правильный формат даты времени, которые изначально сгруппированы по месяцам. Создали признак - срок с момента заключения контракта `term`. И столбец с целевой переменной `target`. Были обнаружены пропуски в столбце `total_charges` замененные пробелом. Данные значения были присвоены тем клиентам которые заключили контракт в том же месяце в котором и производилась выгрузка, значений  всего 12 и так как не понятно уйдут они или останутся в следующем месяце - удалим их.
#
# Разбили столбец с `customer_id` на текстовую и числовую часть, проверим ниже можно ли получить какую либо информацию из них.
# Также добавили признак показывающий меньше платит пользователь чем в среднем за весь срок конракта, возможно пользователь перед тем как расторгнуть контракт уменьшает количество услуг и стоимость оплаты падает.

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# Проверим как рапределена целевая переменная

# %%
plt.figure(figsize=(20,6))
plt.pie(
    df.groupby('target')['customer_id'].count(), 
    labels=['1','0'], 
    autopct='%.1f%%', 
    shadow=True
    )
plt.title('Распределение целевого признака', fontsize=20)
plt.show()

# %% [markdown]
# Больше четверти от общего количества пришедших клиентов

# %% [markdown]
# Посмотрим как менялся приток отток клиентов

# %%
pivot_begin = df.pivot_table(index=df['begin_date'], values='customer_id', aggfunc='count').reset_index().set_index('begin_date')
pivot_end = df.pivot_table(index=df['end_date'], values='customer_id', aggfunc='count').reset_index().set_index('end_date')

pivot_all = pd.concat([pivot_begin, pivot_end], keys=['In', 'Out'], axis=1).fillna(0)
pivot_all = pivot_all.droplevel(level=1, axis=1)
pivot_all.reset_index()
pivot_all = pivot_all[:-1]

# %%
plt.figure(figsize=(18,10))
sns.lineplot(data=pivot_all)
plt.grid(linestyle=':', linewidth=0.7)
plt.xticks(pivot_all.index, rotation=90)
plt

plt.ylim(0, 600)
plt.title('Ежемесячный приток, отток клиентов')
plt.legend(['Заключено', 'Расторгнуто'])
plt.xlabel('Дата')
plt.ylabel('Количество');
plt.yticks(np.arange(0, 550, step=25));

# %% [markdown]
# Видим пик числа заклюений в начале 2014 года, далее приток стабилизировался на 50-100 клиентах ежемесячно, до 2019 года.
# С начала 2019 наблюдался рост притока до 220 клиентов в месяц где и стабилизировался.
#
# Причем как ранее мы заметили что до октября 2019 года клиенты вообще не расторгали договора(как вариант до октября дата расторжения могла не учитываться, либо клиент просто переставал пользоваться услугами не расторгая договор). А с октября до момента выгрузки стабильный отток составляет более 450 клиентов в месяц. Превышая приток в 2-а раза.
#
# Похоже что увеличение притока числа пользователей совпадает с началом резкого ухода. Проверим уходят ли только недавно пришедшие клиенты.

# %%
plt.figure(figsize=(18,10))
sns.lineplot(data=df.query('target == 1').groupby('begin_date')['customer_id'].count())
plt.grid(linestyle=':', linewidth=0.7)
plt.xticks(rotation=90)

plt.ylim(0, 195)
plt.title('Даты регистрации ушедших клиентов')
plt.xlabel('Дата')
plt.ylabel('Количество');

# %% [markdown]
# Отток клиентов равномерно рос в течение 5-х лет и с начала 2019 года рост увеличился в несколько раз. По дате получается уходят в основном новые клиенты.

# %%
plt.figure(figsize=(12, 6))
ax = sns.histplot(
    data=df, 
    x="type", 
    hue="target", 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel'
    )
for c in ax.containers:
    ax.bar_label(c, fmt='%0.1f%%', label_type='edge')
plt.legend(['Текущие клиенты', 'Ушедшие'])
plt.title('Предпочитаемый период оплаты')
plt.xlabel('Тип оплаты')
plt.ylabel('Процент');

# %% [markdown]
# Большая часть ушедших клиентов оплачивали услуги ежемесячно, реже всего уходят те кто платит на два года вперед

# %%
plt.figure(figsize=(12, 6))
ax = sns.histplot(
    data=df, 
    x="paperless_billing", 
    hue="target", 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel'
    )
for c in ax.containers:
    ax.bar_label(c, fmt='%0.1f%%', label_type='edge')
plt.legend(['Текущие клиенты', 'Ушедшие'])
plt.title('Тип счета')
plt.xlabel('Безналичный счет')
plt.ylabel('Процент');

# %% [markdown]
# Большая часть предпочитает безналичный способ оплаты, и процент ушедших среди них выше

# %%
plt.figure(figsize=(12, 6))
ax = sns.histplot(
    data=df, 
    x="payment_method", 
    hue="target", 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel'
    )
for c in ax.containers:
    ax.bar_label(c, fmt='%0.1f%%', label_type='edge')
plt.legend(['Текущие клиенты', 'Ушедшие'])
plt.title('Способ оплаты')
plt.xlabel('Способ оплаты')
plt.ylabel('Процент');

# %% [markdown]
# Треть пользователей платит электронным чеком, из них половина уходит. Остальные способы оплаты вместе с долей ушедших распределены примено равными долями

# %%
#TODO group by 'check' and 'automatic'

# %%
plt.figure(figsize=(18, 6))
sns.histplot(
    data=df, 
    x="monthly_charges", 
    hue="target",
    bins=240, 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel',
    kde=True
    )
plt.xticks(np.arange(15, 120, step=5))
plt.legend(['Текущие клиенты', 'Ушедшие'])
plt.title('Распределение размера абонентской платы')
plt.xlabel('Абонентская плата')
plt.ylabel('Процент');

# %% [markdown]
# Размер абонентской платы групируются вокруг значений кратных 5.

# %%
plt.figure(figsize=(18,3))
plt.title('Распределение размера абонентской платы')
sns.boxplot(x = "monthly_charges", y = "target", data=df, orient='h')
plt.xlim(0, 120);

# %% [markdown]
# У ушедших клиентов стоимость абонентской платы была в среднем выше и распределена более узким диапазоном от 55 до 90 с медианой около 80, в отличии от оставшихся клиентов у которых наиболее частые значения распределены от 25 до 90 с медианой около 65. У ушедших клиентов была более высокая абонентская плата

# %%
plt.figure(figsize=(18, 6))
ax = sns.histplot(
    data=df, 
    x="total_charges", 
    hue="target",
    bins=20, 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel'
    )

for c in ax.containers:
    ax.bar_label(c, fmt='%0.1f%%', label_type='edge')

plt.xticks(np.arange(0, 9000, step=500))
plt.legend(['Текущие клиенты', 'Ушедшие'])
plt.title('Распределение суммы поступивших платежей от клиентов')
plt.xlabel('Сумма платежей')
plt.ylabel('Процент');

# %%
plt.figure(figsize=(18,3))
plt.title('Распределение суммы поступивших платежей от клиентов')
sns.boxplot(x = "total_charges", y = "target", data=df, orient='h')
plt.xlim(-500, 9000);

# %% [markdown]
# Не смотря на более высокую абонентскую плату распределение противоположно размеру абонентской платы - общая сумма поступивших платежей больше у оставшихся клиентов.

# %% [markdown]
# Посмотрим на портрет клиент ушедших и оставшихся клиентов

# %%
fig, axes = plt.subplots(1, 4, figsize=(18,8))

ax1 = sns.histplot(
    data=df, 
    x="gender", 
    hue="target", 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel',
    ax = axes[0])

ax2 = sns.histplot(
    data=df, 
    x="senior_citizen",
    bins=2, 
    hue="target", 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel',
    ax = axes[1])

ax3 = sns.histplot(
    data=df, 
    x="partner", 
    hue="target", 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel',
    ax = axes[2])

ax4 = sns.histplot(
    data=df, 
    x="dependents", 
    hue="target", 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel',
    ax = axes[3])

axes[0].set_title("Распределение по полу")
axes[1].set_title("Пенсионер или нет")
axes[2].set_title("Есть ли супруг(а)")
axes[3].set_title("Наличие иждевенцев")
axes[1].set_xticks(np.arange(0, 2, step=1))

axs = [ax1, ax2, ax3, ax4]

for ax in axs:
    for c in ax.containers:
        ax.bar_label(c, fmt='%0.1f%%', label_type='center')


plt.suptitle("Портрет клиента")



plt.show()

# %% [markdown]
# По полу клиенты распределены практически одинаково, причем и доля ушедших тоже. Следовательно данный признак можно будет не использовать
# Пенсионеров в выборке меньше но доля ушедших среди них около 40%
# Клиентов не сосоящие в отношениях не значительно больше, а доля ушедших среди них выше.
# Клиентов без иждевенцев 70% и доля ушедших среди них чуть выше

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,8))
fig.suptitle('Доля клиентов по основным услугам', fontsize=20)
ax1.pie(
    df.groupby('internet_service')['internet_service'].count(), 
    labels=['Нет','Да'], 
    autopct='%.1f%%', 
    shadow=True,
    )
ax1.set_title('Пользователи услуг Интернет')

ax2.pie(
    df.groupby('phone_service')['phone_service'].count(), 
    labels=['Нет','Да'], 
    autopct='%.1f%%', 
    shadow=True
    )
ax2.set_title('Пользователи услуг телефонии')
plt.show();

# %% [markdown]
# Доля клиентов с услугой телефонии выше чем услуги Интернет

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,8))
fig.suptitle('Доля ушедших клиентов по основным услугам', fontsize=20)
ax1.pie(
    df.query('internet_service == "Yes"').groupby('target')['internet_service'].count(), 
    labels=['Действующие','Ушедшие'], 
    autopct='%.1f%%', 
    shadow=True,
    )
ax1.set_title('Пользователи услуг Интернет')

ax2.pie(
    df.query('phone_service == "Yes"').groupby('target')['phone_service'].count(), 
    labels=['Действующие','Ушедшие'], 
    autopct='%.1f%%', 
    shadow=True
    )
ax2.set_title('Пользователи услуг телефонии')
plt.show();

# %% [markdown]
# Доля ушедших клиентов в разрезе по услугам примерно одинаковы

# %% [markdown]
# Посмотрим какие услуги отличают ушедших клиентов

# %%
sum_services = pd.DataFrame(df[['online_security', 'online_backup', 
                                'device_protection', 'tech_support', 
                                'streaming_tv', 'streaming_movies', 
                                'multiple_lines']].replace({'Yes':1, 'No':0}).sum()).reset_index()
sum_services.columns = ['name', 'sum']

# %%
fig, axes = plt.subplots(2, 4, figsize=(20,12))

ax1 = sns.histplot(data=df, x="online_security", hue="target", multiple="stack", shrink=.9,
    stat='percent', palette='pastel', ax = axes[0, 0])

ax2 = sns.histplot(data=df, x="online_backup", bins=2, hue="target", multiple="stack", shrink=.9,
    stat='percent', palette='pastel', ax = axes[0, 1])

ax3 = sns.histplot(data=df, x="device_protection", hue="target", multiple="stack", shrink=.9,
    stat='percent', palette='pastel', ax = axes[0, 2])

ax4 = sns.histplot(data=df, x="tech_support", hue="target", multiple="stack", shrink=.9,
    stat='percent', palette='pastel', ax = axes[0, 3])

ax5 = sns.histplot(data=df, x="streaming_tv", hue="target", multiple="stack", shrink=.9,
    stat='percent', palette='pastel', ax = axes[1, 0])

ax6 = sns.histplot(data=df, x="streaming_movies", bins=2, hue="target", multiple="stack", shrink=.9,
    stat='percent', palette='pastel', ax = axes[1, 1])

ax7 = sns.histplot(data=df, x="multiple_lines", hue="target", multiple="stack", shrink=.9,
    stat='percent', palette='pastel', ax = axes[1, 2])

ax8 = sns.barplot(data=sum_services, x='name', y='sum', palette='pastel', edgecolor = "black",
    ax = axes[1, 3])

axs = [ax1, ax2, ax3, ax4, ax5, ax6, ax7]
# axes[0].set_title("Распределение по полу")
# axes[1].set_title("Пенсионер или нет")
# axes[2].set_title("Есть ли супруг(а)")
# axes[3].set_title("Наличие иждевенцев")
# axes[1].set_xticks(np.arange(0, 2, step=1))
plt.xticks(rotation=90)         
plt.suptitle("Портрет клиента")
for ax in axs:
    for c in ax.containers:
        ax.bar_label(c, fmt='%0.1f%%', label_type='center')

plt.show()

# %%
plt.figure(figsize=(18, 6))
sns.histplot(
    data=df, 
    x="reduce_increase_services", 
    hue="target",
    bins=50, 
    multiple="stack", 
    shrink=.9,
    stat='percent',
    palette='pastel'
    )
plt.xticks(np.arange(-0.7, 0.7, step=0.1))
plt.legend(['Текущие клиенты', 'Ушедшие'])
plt.title('Распределение размера абонентской платы')
plt.xlabel('Абонентская плата')
plt.ylabel('Процент');

# %%
interval  = ['monthly_charges', 'total_charges', 'senior_citizen', 'target', 'term', 'num_id', 'reduce_increase_services']
phik_overview = df.drop(['customer_id', 'begin_date', 'end_date', 'text_id'], axis=1).phik_matrix(interval_cols=interval)
plt.figure(figsize=(15,12))
plt.title(' ')
sns.heatmap(round(phik_overview, 2), 
            annot=True, 
            vmin=0, 
            vmax=1, 
            center= 0, 
            cmap= 'coolwarm', 
            square=True);

# %%
corr_feat = set()
corr_matrix = phik_overview
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > 0.80:
            colname = corr_matrix.columns[i]
            corr_feat.add(colname)
corr_feat
# Out:
# {'internet_service',
#  'phone_service',
#  'streaming_movies',
#  'streaming_tv',
#  'term'}

# %%
#TODO most popular set of services
#TODO return price of all service

# %%
df['text_id'] = df['text_id'].apply(lambda x: ' '.join(x))

# %%
df.query('target == 1').text_id.str.split(expand=True).stack().value_counts().head()
# Out:
# O    403
# R    397
# H    394
# E    384
# T    376
# dtype: int64

# %%
df.query('target == 0').text_id.str.split(expand=True).stack().value_counts().head()
# Out:
# B    1044
# O    1035
# V    1034
# K    1026
# F    1020
# dtype: int64

# %%
tfidf_transformer = CountVectorizer(analyzer='char')
X_train_tfidf = tfidf_transformer.fit_transform(df['text_id'])
pd.DataFrame(X_train_tfidf)
# Out:
#                                                       0
# 0       (0, 22)\t2\n  (0, 0)\t4\n  (0, 8)\t1\n  (0, ...
# 1       (0, 22)\t1\n  (0, 0)\t4\n  (0, 5)\t1\n  (0, ...
# 2       (0, 0)\t4\n  (0, 17)\t1\n  (0, 16)\t1\n  (0,...
# 3       (0, 0)\t4\n  (0, 3)\t2\n  (0, 6)\t1\n  (0, 1...
# 4       (0, 0)\t4\n  (0, 8)\t1\n  (0, 17)\t1\n  (0, ...
# ...                                                 ...
# 7027    (0, 22)\t1\n  (0, 0)\t4\n  (0, 5)\t1\n  (0, ...
# 7028    (0, 0)\t4\n  (0, 8)\t1\n  (0, 4)\t1\n  (0, 2...
# 7029    (0, 0)\t4\n  (0, 1)\t1\n  (0, 12)\t1\n  (0, ...
# 7030    (0, 0)\t4\n  (0, 4)\t1\n  (0, 11)\t1\n  (0, ...
# 7031    (0, 0)\t4\n  (0, 5)\t1\n  (0, 11)\t1\n  (0, ...
#
# [7032 rows x 1 columns]

# %%
dfs = df.drop(['begin_date', 'end_date', 'customer_id'], axis=1).copy()

# %%
X, y = dfs.drop(['target'], axis=1), df['target']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.25, 
    random_state=47,
    shuffle=True,
    stratify=df['target'])

print('Обучающая выборка:')
print('Доля от общего размера:', round(y_train.shape[0]/df.shape[0], 2))
print('Cтрок, столбцов:', X_train.shape)
print('Доля целевого признака:', round(y_train.mean(), 3))
print('- '*10)


print('Тестовая выборка:')
print('Доля от общего размера:', round(y_test.shape[0]/df.shape[0], 2))
print('Cтрок, столбцов:', X_test.shape)
print('Доля целевого признака:', round(y_test.mean(), 3))
print('-'*30)
# Out:
# Обучающая выборка:
# Доля от общего размера: 0.75
# Cтрок, столбцов: (5274, 22)
# Доля целевого признака: 0.266
# - - - - - - - - - -
# Тестовая выборка:
# Доля от общего размера: 0.25
# Cтрок, столбцов: (1758, 22)
# Доля целевого признака: 0.266
# ------------------------------

# %%
text = ['text_id']
print(f"Текстовый признаки: {text}")
categorical = list(X_train.select_dtypes('object').columns)
categorical.remove('text_id')
print(f"Категориальные признаки: {categorical}")

numerical = list(X_train.select_dtypes('number').columns)
print(f"Числовые признаки: {numerical}")
# Out:
# Текстовый признаки: ['text_id']
# Категориальные признаки: ['type', 'paperless_billing', 'payment_method', 'gender', 'partner', 'dependents', 'internet_service', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies', 'multiple_lines', 'phone_service']
# Числовые признаки: ['monthly_charges', 'total_charges', 'senior_citizen', 'term', 'num_id', 'reduce_increase_services']

# %%
cat_pipe = Pipeline([('encoder', OneHotEncoder(handle_unknown='ignore'))])
num_pipe = Pipeline([('scaler', MinMaxScaler())])
#text_pipe = Pipeline([('hasher', TfidfVectorizer(analyzer='char'))])

preprocessor = ColumnTransformer([
    ('cat', cat_pipe, categorical),
    ('num', num_pipe, numerical),
#    ('text', text_pipe, text)
], remainder="drop")

pipe = Pipeline(
    [
        ('preprocessor', preprocessor),
        ("regressor", LogisticRegression())
    ]
)

param_grid = [
    # {
    #     'regressor': [KNeighborsClassifier()],
    #     # 'regressor__n_neighbors': range(2,40,2),
    #     # 'regressor__leaf_size': range(10,100,2),
    #     # 'regressor__weights': ['uniform', 'distance'],
    #     # 'regressor__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']

    # },
    # {
    #     'regressor': [LogisticRegression(random_state=47)],
    #     'regressor__C': np.linspace(1, 31, 16),
    #     'regressor__solver': ['saga'],
    #     'regressor__max_iter': range(100,2200,200)
    # },
      {
        'regressor': [CatBoostClassifier(random_state=RANDOM_STATE, silent=True)],
        'regressor__iterations': [100, 250, 500],
        'regressor__learning_rate': np.linspace(0.01, 0.5, 10),
        'regressor__depth' : range(4,20,2)
    }
    
]


grid = RandomizedSearchCV(pipe, param_grid, n_iter=250 ,cv=5, scoring = 'roc_auc', verbose=3) #logreg, cat, kmeans mean qty servises

# %%
# %%time
grid.fit(X_train, y_train)
# Out:
# c:\Users\s7\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 240 is smaller than n_iter=250. Running 240 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.838 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.844 total time=   0.4s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.833 total time=   0.5s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.846 total time=   0.5s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.847 total time=   0.5s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.850 total time=   0.5s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.844 total time=   0.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.844 total time=   0.5s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.854 total time=   0.4s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.855 total time=   0.5s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.847 total time=   0.5s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.839 total time=   0.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.844 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.850 total time=   0.8s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.857 total time=   0.5s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.842 total time=   0.7s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.832 total time=   0.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.841 total time=   0.5s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.846 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.848 total time=   0.4s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.833 total time=   0.5s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.830 total time=   0.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.842 total time=   0.4s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.846 total time=   0.5s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.847 total time=   0.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.830 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.819 total time=   0.8s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.834 total time=   0.9s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.839 total time=   0.7s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.845 total time=   0.8s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.829 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.817 total time=   0.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.829 total time=   0.5s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.839 total time=   0.5s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.846 total time=   0.5s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.826 total time=   0.5s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.821 total time=   0.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.821 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.834 total time=   0.5s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.831 total time=   0.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.805 total time=   0.5s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.811 total time=   0.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.820 total time=   0.5s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.829 total time=   0.5s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.833 total time=   0.5s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.802 total time=   0.5s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.807 total time=   0.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.817 total time=   0.5s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.830 total time=   0.5s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.834 total time=   0.5s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.844 total time=   1.0s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.847 total time=   1.1s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.841 total time=   1.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.849 total time=   1.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.853 total time=   1.0s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.846 total time=   1.1s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.836 total time=   1.0s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.839 total time=   1.3s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.851 total time=   1.1s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.851 total time=   1.0s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.837 total time=   1.0s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.829 total time=   0.9s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.835 total time=   1.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.845 total time=   1.0s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.848 total time=   1.1s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.823 total time=   1.0s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.819 total time=   1.1s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.831 total time=   1.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.843 total time=   1.3s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.839 total time=   1.7s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.817 total time=   1.1s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.813 total time=   1.2s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.828 total time=   0.9s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.836 total time=   1.0s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.833 total time=   0.9s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.2822222222222222;, score=0.817 total time=   1.1s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.2822222222222222;, score=0.802 total time=   0.9s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.2822222222222222;, score=0.813 total time=   1.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.2822222222222222;, score=0.825 total time=   1.3s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.2822222222222222;, score=0.826 total time=   1.0s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.33666666666666667;, score=0.819 total time=   1.1s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.33666666666666667;, score=0.808 total time=   0.9s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.33666666666666667;, score=0.819 total time=   0.9s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.33666666666666667;, score=0.825 total time=   0.9s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.33666666666666667;, score=0.829 total time=   1.1s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.3911111111111111;, score=0.810 total time=   1.0s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.3911111111111111;, score=0.805 total time=   1.0s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.3911111111111111;, score=0.812 total time=   0.8s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.3911111111111111;, score=0.814 total time=   0.9s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.3911111111111111;, score=0.821 total time=   0.9s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.44555555555555554;, score=0.791 total time=   0.9s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.44555555555555554;, score=0.799 total time=   0.9s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.44555555555555554;, score=0.807 total time=   1.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.44555555555555554;, score=0.815 total time=   0.9s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.44555555555555554;, score=0.824 total time=   0.9s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.5;, score=0.792 total time=   0.9s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.5;, score=0.790 total time=   0.9s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.5;, score=0.802 total time=   0.9s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.5;, score=0.813 total time=   0.9s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=250, regressor__learning_rate=0.5;, score=0.822 total time=   0.9s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.849 total time=   1.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.847 total time=   1.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.845 total time=   1.7s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.852 total time=   1.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.856 total time=   1.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.833 total time=   1.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.826 total time=   1.8s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.834 total time=   1.8s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.846 total time=   1.7s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.843 total time=   1.7s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.826 total time=   1.5s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.817 total time=   1.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.826 total time=   1.5s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.835 total time=   1.5s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.839 total time=   1.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.812 total time=   1.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.810 total time=   1.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.817 total time=   1.5s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.831 total time=   1.7s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.830 total time=   2.1s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.810 total time=   1.7s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.806 total time=   1.9s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.818 total time=   2.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.823 total time=   1.7s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.823 total time=   1.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.807 total time=   1.7s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.792 total time=   1.9s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.808 total time=   2.1s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.821 total time=   1.7s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.823 total time=   1.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.811 total time=   1.8s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.798 total time=   1.7s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.805 total time=   1.7s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.818 total time=   1.7s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.819 total time=   1.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.804 total time=   1.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.795 total time=   1.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.803 total time=   1.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.814 total time=   1.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.820 total time=   1.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.44555555555555554;, score=0.785 total time=   1.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.44555555555555554;, score=0.791 total time=   1.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.44555555555555554;, score=0.803 total time=   1.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.44555555555555554;, score=0.806 total time=   1.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.44555555555555554;, score=0.820 total time=   1.5s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.5;, score=0.783 total time=   1.7s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.5;, score=0.786 total time=   2.0s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.5;, score=0.800 total time=   1.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.5;, score=0.803 total time=   1.8s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=4, regressor__iterations=500, regressor__learning_rate=0.5;, score=0.818 total time=   1.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.841 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.844 total time=   0.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.839 total time=   0.8s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.847 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.01;, score=0.850 total time=   0.9s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.846 total time=   0.8s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.840 total time=   0.8s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.845 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.848 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.06444444444444444;, score=0.852 total time=   0.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.830 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.834 total time=   0.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.840 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.841 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.11888888888888888;, score=0.854 total time=   0.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.833 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.824 total time=   0.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.828 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.840 total time=   0.8s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.17333333333333334;, score=0.845 total time=   0.8s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.821 total time=   0.7s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.818 total time=   0.8s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.835 total time=   0.7s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.835 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.22777777777777777;, score=0.831 total time=   0.7s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.817 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.814 total time=   0.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.819 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.826 total time=   0.8s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.2822222222222222;, score=0.843 total time=   0.7s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.816 total time=   1.0s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.814 total time=   0.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.824 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.828 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.33666666666666667;, score=0.830 total time=   0.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.806 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.808 total time=   0.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.812 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.817 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.3911111111111111;, score=0.829 total time=   0.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.804 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.809 total time=   0.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.821 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.814 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.44555555555555554;, score=0.829 total time=   0.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.799 total time=   0.6s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.791 total time=   0.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.814 total time=   0.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.804 total time=   0.6s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=100, regressor__learning_rate=0.5;, score=0.822 total time=   0.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.845 total time=   1.3s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.846 total time=   1.3s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.843 total time=   1.3s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.850 total time=   1.3s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.01;, score=0.854 total time=   1.3s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.836 total time=   1.4s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.829 total time=   1.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.837 total time=   1.2s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.838 total time=   1.3s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.06444444444444444;, score=0.846 total time=   1.3s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.815 total time=   1.3s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.826 total time=   1.3s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.829 total time=   1.2s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.829 total time=   1.3s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.11888888888888888;, score=0.846 total time=   1.3s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.819 total time=   1.3s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.810 total time=   1.3s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.818 total time=   1.3s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.824 total time=   1.3s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.17333333333333334;, score=0.831 total time=   1.3s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.805 total time=   1.3s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.811 total time=   1.3s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.820 total time=   1.4s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.826 total time=   1.3s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.22777777777777777;, score=0.828 total time=   1.3s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.2822222222222222;, score=0.813 total time=   1.3s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=6, regressor__iterations=250, regressor__learning_rate=0.2822222222222222;, score=0.805 total time=   1.2s
# ...
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.833 total time=  22.3s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.835 total time=  22.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.841 total time=  21.2s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.01;, score=0.845 total time=  22.0s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.822 total time=  20.4s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.808 total time=  21.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.816 total time=  20.6s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.823 total time=  20.2s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.06444444444444444;, score=0.834 total time=  24.3s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.811 total time=  16.9s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.806 total time=  17.0s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.815 total time=  17.3s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.823 total time=  16.7s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.11888888888888888;, score=0.824 total time=  17.0s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.803 total time=  16.7s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.809 total time=  16.5s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.817 total time=  16.7s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.818 total time=  16.7s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.17333333333333334;, score=0.829 total time=  21.2s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.811 total time=  15.1s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.805 total time=  15.2s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.810 total time=  16.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.810 total time=  14.9s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.22777777777777777;, score=0.823 total time=  15.0s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.804 total time=  15.1s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.803 total time=  15.8s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.810 total time=  15.4s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.809 total time=  15.4s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.2822222222222222;, score=0.829 total time=  15.3s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.802 total time=  15.8s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.796 total time=  15.3s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.814 total time=  15.3s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.810 total time=  15.3s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.33666666666666667;, score=0.812 total time=  16.5s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.795 total time=  15.4s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.792 total time=  15.7s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.808 total time=  15.0s
# [CV 4/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.814 total time=  19.1s
# [CV 5/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.3911111111111111;, score=0.812 total time=  16.6s
# [CV 1/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.44555555555555554;, score=0.803 total time=  14.2s
# [CV 2/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.44555555555555554;, score=0.796 total time=  14.6s
# [CV 3/5] END regressor=<catboost.core.CatBoostClassifier object at 0x00000295DEC40A90>, regressor__depth=10, regressor__iterations=500, regressor__learning_rate=0.44555555555555554;, score=0.808 total time=  15.5s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# c:\Users\s7\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# c:\Users\s7\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1766     def _run_search(self, evaluate_candidates):
#    1767         """Search n_iter candidates from param_distributions"""
# -> 1768         evaluate_candidates(
#    1769             ParameterSampler(
#    1770                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# c:\Users\s7\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# c:\Users\s7\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# c:\Users\s7\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1086                 self._iterating = self._original_iterator is not None
#    1087
# -> 1088             while self.dispatch_one_batch(iterator):
#    1089                 pass
#    1090
#
# c:\Users\s7\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# c:\Users\s7\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# c:\Users\s7\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\Users\s7\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# c:\Users\s7\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# c:\Users\s7\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# c:\Users\s7\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# c:\Users\s7\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# c:\Users\s7\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     403             if self._final_estimator != "passthrough":
#     404                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     406
#     407         return self
#
# c:\Users\s7\anaconda3\lib\site-packages\catboost\core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5126             CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
#    5127
# -> 5128         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5129                   eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5130                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# c:\Users\s7\anaconda3\lib\site-packages\catboost\core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2353         with log_fixup(log_cout, log_cerr), \
#    2354             plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2355             self._train(
#    2356                 train_pool,
#    2357                 train_params["eval_sets"],
#
# c:\Users\s7\anaconda3\lib\site-packages\catboost\core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1757
#    1758     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1759         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1760         self._set_trained_model_attributes()
#    1761
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
result = pd.DataFrame(grid.cv_results_)

result.sort_values('mean_test_score', ascending=False)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.696926      0.037776         0.025199        0.000934
# 1       0.717188      0.022107         0.025698        0.001083
# 2       0.742355      0.056061         0.024592        0.000800
# 3       0.682133      0.011167         0.024278        0.000630
# 4       0.717291      0.021667         0.025396        0.001829
# 5       0.648945      0.017590         0.024497        0.001000
# 7       0.712929      0.020705         0.025599        0.001933
# 8       0.766034      0.073162         0.025995        0.002532
# 6       0.727842      0.066031         0.024638        0.001143
# 9       0.794754      0.056307         0.029797        0.001330
#
#   param_regressor__learning_rate param_regressor__iterations  \
# 0                            0.1                         100
# 1                            0.2                         100
# 2                            0.3                         100
# 3                            0.4                         100
# 4                            0.5                         100
# 5                            0.6                         100
# 7                            0.8                         100
# 8                            0.9                         100
# 6                            0.7                         100
# 9                            1.0                         100
#
#                                      param_regressor  \
# 0  <catboost.core.CatBoostClassifier object at 0x...
# 1  <catboost.core.CatBoostClassifier object at 0x...
# 2  <catboost.core.CatBoostClassifier object at 0x...
# 3  <catboost.core.CatBoostClassifier object at 0x...
# 4  <catboost.core.CatBoostClassifier object at 0x...
# 5  <catboost.core.CatBoostClassifier object at 0x...
# 7  <catboost.core.CatBoostClassifier object at 0x...
# 8  <catboost.core.CatBoostClassifier object at 0x...
# 6  <catboost.core.CatBoostClassifier object at 0x...
# 9  <catboost.core.CatBoostClassifier object at 0x...
#
#                                               params  split0_test_score  \
# 0  {'regressor__learning_rate': 0.1, 'regressor__...           0.838475
# 1  {'regressor__learning_rate': 0.2, 'regressor__...           0.827788
# 2  {'regressor__learning_rate': 0.300000000000000...           0.817853
# 3  {'regressor__learning_rate': 0.4, 'regressor__...           0.806408
# 4  {'regressor__learning_rate': 0.5, 'regressor__...           0.798848
# 5  {'regressor__learning_rate': 0.6, 'regressor__...           0.792832
# 7  {'regressor__learning_rate': 0.8, 'regressor__...           0.799682
# 8  {'regressor__learning_rate': 0.9, 'regressor__...           0.776212
# 6  {'regressor__learning_rate': 0.700000000000000...           0.782728
# 9  {'regressor__learning_rate': 1.0, 'regressor__...           0.773546
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.836124           0.843591           0.844019           0.853428
# 1           0.827037           0.833379           0.836230           0.839396
# 2           0.796829           0.821678           0.824722           0.825217
# 3           0.812263           0.812625           0.819094           0.827944
# 4           0.791290           0.813908           0.804307           0.822255
# 5           0.802194           0.801337           0.792302           0.816510
# 7           0.778811           0.789944           0.784679           0.801403
# 8           0.783461           0.791111           0.794992           0.808375
# 6           0.792820           0.780109           0.784146           0.813806
# 9           0.777138           0.778100           0.788390           0.798726
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.843127        0.005963                1
# 1         0.832766        0.004774                2
# 2         0.817260        0.010548                3
# 3         0.815667        0.007335                4
# 4         0.806122        0.010928                5
# 5         0.801035        0.008769                6
# 7         0.790904        0.008639                7
# 8         0.790830        0.010892                8
# 6         0.790722        0.012305                9
# 9         0.783180        0.009208               10
