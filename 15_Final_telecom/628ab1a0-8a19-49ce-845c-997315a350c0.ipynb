# %% [markdown]
# <h1> Комментарий тимлида </h1>
#
# 👋 **Приветствую, Евгений!**
#
# ✨ Поздравляю с началом работы над финальным проектом!
#
# Меня зовут Арсен Абдулин и я буду твоим ревьювером. Помню, однажды проверял твой проект =)
#
# При проверке работ я пишу следующие комментарии:
#
# <div class="alert alert-success">
# <b>✔️ Зеленым цветом</b> отмечены удачные решения.</div>
#
# <div class="alert alert-warning">
# <b>⚠️ Желтым цветом</b> я отметил пункты, которые в следующий раз можно сделать по-другому. Одно-два таких замечания в проекте допускается, но если их много — проект следует доработать. </div>
#
# <div class="alert alert-danger">
# <b>🚫 Красным цветом</b> отмечены критические замечания, которые необходимо поправить, чтобы принять проект. </div>
#
# Если какие-то моменты в задании для тебя были непонятны и у тебя есть ко мне вопросы — смело спрашивай 😊 Также ты можешь доработать места, где есть желтые комментарии в проекте (однако, это не обязательно).
#
# Предлагаю работать в диалоге: если ты решишь что-то поменять по моим рекомендациям — пиши об этом (выбери для своих комментариев определенный цвет - так мне будет легче увидеть изменения). Пожалуйста не перемещай, не изменяй и не удаляй мои комментарии. Все это поможет сделать проверку твоего проекта оперативнее.
#
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Пример комментария. </div>

# %% [markdown]
# Вопросов, пока особо нет

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Принято!
#
# </div>

# %% [markdown]
# # Отток клиентов телеком компании

# %% [markdown]
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Хорошо, когда есть описание проекта и обозначения признаков — так гораздо проще ознакомиться!
#
# </div>

# %% [markdown]
# ### Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL, от англ. digital subscriber line, «цифровая абонентская линия») или оптоволоконный кабель (Fiber optic).
#
# Также доступны такие услуги:
# - Интернет-безопасность: антивирус (DeviceProtection) и блокировка небезопасных сайтов (OnlineSecurity);
# - Выделенная линия технической поддержки (TechSupport);
# - Облачное хранилище файлов для резервного копирования данных (OnlineBackup);
# - Стриминговое телевидение (StreamingTV) и каталог фильмов (StreamingMovies).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.
#
# ###  Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
# * `contract.csv` — информация о договоре;
# * `personal.csv` — персональные данные клиента;
# * `internet.csv` — информация об интернет-услугах;
# * `phone.csv` — информация об услугах телефонии.
#
# В данных предоставлены следующие признаки:
# + BeginDate – дата начала пользования услугами,
# + EndDate – дата окончания пользования услугами,
# + Type – тип оплаты: ежемесячный, годовой и тд,
# + PaperlessBilling – безналичный расчет,
# + PaymentMethod – способ оплаты,
# + MonthlyCharges – ежемесячные траты на услуги,
# + TotalCharges – всего потрачено денег на услуги
# + Dependents – наличие иждивенцев
# + Senior Citizen – наличие пенсионного статуса по возрасту
# + Partner – наличие супруга(и)
# + MultipleLines – наличие возможности ведения параллельных линий во время
# звонка
#
#
# Во всех файлах столбец customerID содержит код клиента.
# Информация о договорах актуальна на 1 февраля 2020.
#
# ### План работы
# 1. Загрузка и ознакомление с данными
#     + загрузка необходимых библиотек
#     + загрузка данных
#     + ознакомление и обозначение проблем для этапа предобработки
# 2. Предварительная обработка данных
#     + объединение данных
#     + обработка пропусков
#     + преобразование типов
#     + добавление новых признаков
# 3. Исследовательский анализ
#     + проверка распределений данных
#     + проверка зависимостей целевой переменной
#     + формирование и проверка гипотез
# 4. Подготовка и обучение модели
#     + разбиение данных на тренировочную и тестовую выборки
#     + создание несколько моделей (pipeline c CV)
#     + обучение и определение лучшей модели
# 5. Проверка работы модели
#     + проверка на тестовой выборке
#     + анализ результатов работы модели
# 6. Вывод
#     + вывод
#     + параметры финальной модели
#
# ### Критерии оценки работы
#
# Основная метрика: **AUC-ROC**\
# Дополнительная метрика: **Accuracy**\
# Критерии оценки: **AUC-ROC >= 0.85**

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> План работ последовательный и понятный, замечаний нет!
#
# </div>

# %% [markdown]
# ## Загрузка и ознакомление с данными

# %% [markdown]
# Загрузим необходимые библиотеки

# %%
# %pip install phik

# %%
import os
import re
from IPython.display import display

import matplotlib.pyplot as plt
import numpy as np
import phik
#from phik.report import plot_correlation_matrix
#from phik import report
import pandas as pd
import seaborn as sns

# %% [markdown]
# Зафиксируем глобальные переменные

# %%
MY_DIR = 'data/'
YA_DIR = '/datasets/final_provider/'
RANDOM_STATE = 270223

# %% [markdown]
# Считаем данные

# %%
def search_and_var_naming(dir):
    """
    Search all *.csv files in dir and creat dic varname:filepath
    dir -- directory with data
    sep -- win/lin filepath sep
    """
    csv_files = {}
    for root, dirs, files in os.walk(dir):
        counter = 0
        for file in files:
            if file.endswith(".csv"):
                counter += 1
                csv_files[file.split('.')[0]] = dir + file
        if counter == 0:
            print('В папке отсутствуют файлы формата *.csv')
        else:
            print(f'Количество найденных файлов *.csv: {counter}')
    return csv_files

# %%
if os.path.exists(MY_DIR):
    print('Используется локальная папка')
    files_and_path = search_and_var_naming(MY_DIR)
elif os.path.exists(YA_DIR):
    print('Используется репозиторий Yandex')    
    files_and_path = search_and_var_naming(YA_DIR)
else:
    print('Папка с данными не найдена')
# Out:
# Используется локальная папка
# Количество найденных файлов *.csv: 4

# %% [markdown]
# Преобразуем и присвоим найденным файлам имена в соответствии с их названием

# %%
for key in files_and_path:
    exec(f'{key} = pd.read_csv(files_and_path[key])')
    print(key)
# Out:
# contract
# internet
# personal
# phone

# %%
files = [contract, internet, personal, phone]

# %% [markdown]
# Преобразуем имена колонок в snake_case

# %%
for file in files:
    new_columns_name=[]
    for column in file.columns:
        new_columns_name.append(re.sub('(?!^)([A-Z]+)', r'_\1', column).lower())
    file.columns = new_columns_name

# %% [markdown]
# ### Последовательно изучим общую информацию о всех представленных данных

# %% [markdown]
# #### contract

# %%
def base_info(df:pd.DataFrame):
    """
    Display some base info about df
    head, tail, info, describe
    """
    print('Head')
    display(df.head())
    print('*'*120)
    print('Tail')
    display(df.tail())
    print('*'*120)   
    print('Info')
    df.info()
    print('*'*120)
    print('Describe')
    display(df.describe(include='all'))

# %%
base_info(contract)
# Out:
# Head
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperless_billing             payment_method  monthly_charges total_charges
# 0               Yes           Electronic check            29.85         29.85
# 1                No               Mailed check            56.95        1889.5
# 2               Yes               Mailed check            53.85        108.15
# 3                No  Bank transfer (automatic)            42.30       1840.75
# 4               Yes           Electronic check            70.70        151.65
# ************************************************************************************************************************
# Tail
#      customer_id  begin_date             end_date            type  \
# 7038  6840-RESVB  2018-02-01                   No        One year
# 7039  2234-XADUH  2014-02-01                   No        One year
# 7040  4801-JZAZL  2019-03-01                   No  Month-to-month
# 7041  8361-LTMKD  2019-07-01  2019-11-01 00:00:00  Month-to-month
# 7042  3186-AJIEK  2014-08-01                   No        Two year
#
#      paperless_billing             payment_method  monthly_charges  \
# 7038               Yes               Mailed check            84.80
# 7039               Yes    Credit card (automatic)           103.20
# 7040               Yes           Electronic check            29.60
# 7041               Yes               Mailed check            74.40
# 7042               Yes  Bank transfer (automatic)           105.65
#
#      total_charges
# 7038        1990.5
# 7039        7362.9
# 7040        346.45
# 7041         306.6
# 7042        6844.5
# ************************************************************************************************************************
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
# ************************************************************************************************************************
# Describe
#        customer_id  begin_date end_date            type paperless_billing  \
# count         7043        7043     7043            7043              7043
# unique        7043          77        5               3                 2
# top     7590-VHVEG  2014-02-01       No  Month-to-month               Yes
# freq             1         366     5174            3875              4171
# mean           NaN         NaN      NaN             NaN               NaN
# std            NaN         NaN      NaN             NaN               NaN
# min            NaN         NaN      NaN             NaN               NaN
# 25%            NaN         NaN      NaN             NaN               NaN
# 50%            NaN         NaN      NaN             NaN               NaN
# 75%            NaN         NaN      NaN             NaN               NaN
# max            NaN         NaN      NaN             NaN               NaN
#
#           payment_method  monthly_charges total_charges
# count               7043      7043.000000          7043
# unique                 4              NaN          6531
# top     Electronic check              NaN
# freq                2365              NaN            11
# mean                 NaN        64.761692           NaN
# std                  NaN        30.090047           NaN
# min                  NaN        18.250000           NaN
# 25%                  NaN        35.500000           NaN
# 50%                  NaN        70.350000           NaN
# 75%                  NaN        89.850000           NaN
# max                  NaN       118.750000           NaN

# %% [markdown]
# Явные пропуски отсутствуют.
# + `begin_date` - необходимо будет преобразовать в формат даты и при анализе проверить утверждение, чем более долгий срок клиент с компанией тем меньшая вероятность его ухода
# + `end_date` - целевой признак, если клиент ушел дата будет обозначена также необходимо преобразовать в формат даты, и преобразовать с `begin_date` в срок обслуживания
# + `total_charges` - проверим на пропуски и преобразуем в числовой
# + `monthly_charges` - тип данных ожидаемый, проверим если средний чек совпадает 'кол-во месяцев' / `total_charges` == `monthly_charges`, то клиент не увеличивал кол-во услуг, меньше -> отказывался, больше -> добавлял

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Данные загружены успешно! Хорошо, что сделал подробный анализ данных, видно что нужна дальнейшая предобработка
#
# </div>

# %% [markdown]
# Количество уникальных ID совпадает с количеством строк, следовательно полные дубликаты отсутствуют. Попробывать разбить преобразовать в хэш текстовую часть а цифровую посмотреть может в ней регион, офис и т.д, может быть корреляция с датой то удалим

# %%
contract.paperless_billing.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# `paperless_billing` - уникальные значения да/нет

# %%
contract.payment_method.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %% [markdown]
# `payment_method` варианты платежей, проверим на зависимость с `paperless_billing` и на возможность объединения по методу платежа check/automatic

# %%
contract.type.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# `type` - тип платежа, логично будет преположить что чем на более длительный срок клиент оплачивает услуги тем меньше вероятность его ухода, проверим при анализе данных

# %% [markdown]
# #### internet

# %%
base_info(internet)
# Out:
# Head
#   customer_id internet_service online_security online_backup  \
# 0  7590-VHVEG              DSL              No           Yes
# 1  5575-GNVDE              DSL             Yes            No
# 2  3668-QPYBK              DSL             Yes           Yes
# 3  7795-CFOCW              DSL             Yes            No
# 4  9237-HQITU      Fiber optic              No            No
#
#   device_protection tech_support streaming_tv streaming_movies
# 0                No           No           No               No
# 1               Yes           No           No               No
# 2                No           No           No               No
# 3               Yes          Yes           No               No
# 4                No           No           No               No
# ************************************************************************************************************************
# Tail
#      customer_id internet_service online_security online_backup  \
# 5512  6840-RESVB              DSL             Yes            No
# 5513  2234-XADUH      Fiber optic              No           Yes
# 5514  4801-JZAZL              DSL             Yes            No
# 5515  8361-LTMKD      Fiber optic              No            No
# 5516  3186-AJIEK      Fiber optic             Yes            No
#
#      device_protection tech_support streaming_tv streaming_movies
# 5512               Yes          Yes          Yes              Yes
# 5513               Yes           No          Yes              Yes
# 5514                No           No           No               No
# 5515                No           No           No               No
# 5516               Yes          Yes          Yes              Yes
# ************************************************************************************************************************
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        5517 non-null   object
#  1   internet_service   5517 non-null   object
#  2   online_security    5517 non-null   object
#  3   online_backup      5517 non-null   object
#  4   device_protection  5517 non-null   object
#  5   tech_support       5517 non-null   object
#  6   streaming_tv       5517 non-null   object
#  7   streaming_movies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
# ************************************************************************************************************************
# Describe
#        customer_id internet_service online_security online_backup  \
# count         5517             5517            5517          5517
# unique        5517                2               2             2
# top     7590-VHVEG      Fiber optic              No            No
# freq             1             3096            3498          3088
#
#        device_protection tech_support streaming_tv streaming_movies
# count               5517         5517         5517             5517
# unique                 2            2            2                2
# top                   No           No           No               No
# freq                3095         3473         2810             2785

# %%
internet.internet_service.unique()
# Out:
# array(['DSL', 'Fiber optic'], dtype=object)

# %% [markdown]
# Значений меньше чем в `contract` - не все пользователи пользуются услугой интернет. В столбце internet_service два вида подключения. В остальных подключена ли услуга да/нет
# Преобразование типов не требуется

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Все верно, не все клиенты пользуются интернет-услугами
#
# </div>

# %% [markdown]
# Сделаем проверку для будущего объеденения

# %%
len(internet[~internet['customer_id'].isin(contract['customer_id'])])
# Out:
# 0

# %% [markdown]
# #### personal

# %%
base_info(personal)
# Out:
# Head
#   customer_id  gender  senior_citizen partner dependents
# 0  7590-VHVEG  Female               0     Yes         No
# 1  5575-GNVDE    Male               0      No         No
# 2  3668-QPYBK    Male               0      No         No
# 3  7795-CFOCW    Male               0      No         No
# 4  9237-HQITU  Female               0      No         No
# ************************************************************************************************************************
# Tail
#      customer_id  gender  senior_citizen partner dependents
# 7038  6840-RESVB    Male               0     Yes        Yes
# 7039  2234-XADUH  Female               0     Yes        Yes
# 7040  4801-JZAZL  Female               0     Yes        Yes
# 7041  8361-LTMKD    Male               1     Yes         No
# 7042  3186-AJIEK    Male               0      No         No
# ************************************************************************************************************************
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     7043 non-null   object
#  1   gender          7043 non-null   object
#  2   senior_citizen  7043 non-null   int64
#  3   partner         7043 non-null   object
#  4   dependents      7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# ************************************************************************************************************************
# Describe
#        customer_id gender  senior_citizen partner dependents
# count         7043   7043     7043.000000    7043       7043
# unique        7043      2             NaN       2          2
# top     7590-VHVEG   Male             NaN      No         No
# freq             1   3555             NaN    3641       4933
# mean           NaN    NaN        0.162147     NaN        NaN
# std            NaN    NaN        0.368612     NaN        NaN
# min            NaN    NaN        0.000000     NaN        NaN
# 25%            NaN    NaN        0.000000     NaN        NaN
# 50%            NaN    NaN        0.000000     NaN        NaN
# 75%            NaN    NaN        0.000000     NaN        NaN
# max            NaN    NaN        1.000000     NaN        NaN

# %%
personal.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
personal.senior_citizen.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Значения в остальных столбцах да/нет

# %% [markdown]
# Проверка

# %%
len(personal[~personal['customer_id'].isin(contract['customer_id'])])
# Out:
# 0

# %% [markdown]
# #### phone

# %%
base_info(phone)
# Out:
# Head
#   customer_id multiple_lines
# 0  5575-GNVDE             No
# 1  3668-QPYBK             No
# 2  9237-HQITU             No
# 3  9305-CDSKC            Yes
# 4  1452-KIOVK            Yes
# ************************************************************************************************************************
# Tail
#      customer_id multiple_lines
# 6356  2569-WGERO             No
# 6357  6840-RESVB            Yes
# 6358  2234-XADUH            Yes
# 6359  8361-LTMKD            Yes
# 6360  3186-AJIEK             No
# ************************************************************************************************************************
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     6361 non-null   object
#  1   multiple_lines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# ************************************************************************************************************************
# Describe
#        customer_id multiple_lines
# count         6361           6361
# unique        6361              2
# top     5575-GNVDE             No
# freq             1           3390

# %% [markdown]
# phone - содержит информацию о пользователях телефоном и подключена ли услуга нескольких линий

# %%
len(phone[~phone['customer_id'].isin(contract['customer_id'])])
# Out:
# 0

# %% [markdown]
# ### Вывод:

# %% [markdown]
# В данном разделе мы провели загрузку и предварительное ознакомление с данными. Данные представлены в виде 4х файлов формата *.csv.
# Переименовали столбцы в более удобный формат для работы. Датафреймам присвоили имена соответственно именам файлов из которых загружали
#
# `contract` Данные предоставлены с 2014-02-01 по . 7043 строки  по 8 признаков. Пропуски и дубликаты не найдены. Обнаружены несоответствия типов данных. Из двух столбцов даты начала контракта и его окончания необходимо будет сформировать длительность пользования услугами, и выделить целевую переменную - факт окончания контракта.
#
# `internet` 5517 клиентов с 8-ю признаками. Преобразования не требуются.
#
# `personal` 7043 строки с 5-ю признаками. Признак `senior_citizen` кодирован 1/0 вместо обычного yes/no
#
# `phone` 6361 строка с 2-я признаками
#
# Во всех таблица первичным ключом является `customer_id` по нему будем производить объединение таблиц.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Все хорошо, данные готовы для объединения таблиц!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> План работ принят, можно приступать к основному проекту.
#
# Пожалуйста сохрани наши с тобой комментарии, а проект продолжай делать в этом же документе, успехов!
#
# </div>

# %% [markdown]
# ## Предварительная обработка данных

# %% [markdown]
# Сведем все данные в единый датафрейм

# %% [markdown]
# Перед сведение добавим индикаторные столбцы наличия услуг интернет и телефона

# %%
df = contract.merge(personal, how='left', on='customer_id')
df = df.merge(internet, how='left', on='customer_id')
df = df.merge(phone, how='left', on='customer_id')

# %%
pd.DataFrame({'NaNs, %': round((df.isna().mean()*100),2), 
              'NaNs, qty': df.isna().sum()}).style.format('{:.2f}').background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_e672e_row0_col0, #T_e672e_row0_col1, #T_e672e_row1_col0, #T_e672e_row1_col1, #T_e672e_row2_col0, #T_e672e_row2_col1, #T_e672e_row3_col0, #T_e672e_row3_col1, #T_e672e_row4_col0, #T_e672e_row4_col1, #T_e672e_row5_col0, #T_e672e_row5_col1, #T_e672e_row6_col0, #T_e672e_row6_col1, #T_e672e_row7_col0, #T_e672e_row7_col1, #T_e672e_row8_col0, #T_e672e_row8_col1, #T_e672e_row9_col0, #T_e672e_row9_col1, #T_e672e_row10_col0, #T_e672e_row10_col1, #T_e672e_row11_col0, #T_e672e_row11_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e672e_row12_col0, #T_e672e_row12_col1, #T_e672e_row13_col0, #T_e672e_row13_col1, #T_e672e_row14_col0, #T_e672e_row14_col1, #T_e672e_row15_col0, #T_e672e_row15_col1, #T_e672e_row16_col0, #T_e672e_row16_col1, #T_e672e_row17_col0, #T_e672e_row17_col1, #T_e672e_row18_col0, #T_e672e_row18_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e672e_row19_col0, #T_e672e_row19_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# </style>
# <table id="T_e672e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NaNs, %</th>
#       <th class="col_heading level0 col1" >NaNs, qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e672e_level0_row0" class="row_heading level0 row0" >customer_id</th>
#       <td id="T_e672e_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_e672e_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row1" class="row_heading level0 row1" >begin_date</th>
#       <td id="T_e672e_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_e672e_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row2" class="row_heading level0 row2" >end_date</th>
#       <td id="T_e672e_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_e672e_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row3" class="row_heading level0 row3" >type</th>
#       <td id="T_e672e_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_e672e_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row4" class="row_heading level0 row4" >paperless_billing</th>
#       <td id="T_e672e_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_e672e_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row5" class="row_heading level0 row5" >payment_method</th>
#       <td id="T_e672e_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_e672e_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row6" class="row_heading level0 row6" >monthly_charges</th>
#       <td id="T_e672e_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_e672e_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row7" class="row_heading level0 row7" >total_charges</th>
#       <td id="T_e672e_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_e672e_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row8" class="row_heading level0 row8" >gender</th>
#       <td id="T_e672e_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_e672e_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row9" class="row_heading level0 row9" >senior_citizen</th>
#       <td id="T_e672e_row9_col0" class="data row9 col0" >0.00</td>
#       <td id="T_e672e_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row10" class="row_heading level0 row10" >partner</th>
#       <td id="T_e672e_row10_col0" class="data row10 col0" >0.00</td>
#       <td id="T_e672e_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row11" class="row_heading level0 row11" >dependents</th>
#       <td id="T_e672e_row11_col0" class="data row11 col0" >0.00</td>
#       <td id="T_e672e_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row12" class="row_heading level0 row12" >internet_service</th>
#       <td id="T_e672e_row12_col0" class="data row12 col0" >21.67</td>
#       <td id="T_e672e_row12_col1" class="data row12 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row13" class="row_heading level0 row13" >online_security</th>
#       <td id="T_e672e_row13_col0" class="data row13 col0" >21.67</td>
#       <td id="T_e672e_row13_col1" class="data row13 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row14" class="row_heading level0 row14" >online_backup</th>
#       <td id="T_e672e_row14_col0" class="data row14 col0" >21.67</td>
#       <td id="T_e672e_row14_col1" class="data row14 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row15" class="row_heading level0 row15" >device_protection</th>
#       <td id="T_e672e_row15_col0" class="data row15 col0" >21.67</td>
#       <td id="T_e672e_row15_col1" class="data row15 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row16" class="row_heading level0 row16" >tech_support</th>
#       <td id="T_e672e_row16_col0" class="data row16 col0" >21.67</td>
#       <td id="T_e672e_row16_col1" class="data row16 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row17" class="row_heading level0 row17" >streaming_tv</th>
#       <td id="T_e672e_row17_col0" class="data row17 col0" >21.67</td>
#       <td id="T_e672e_row17_col1" class="data row17 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row18" class="row_heading level0 row18" >streaming_movies</th>
#       <td id="T_e672e_row18_col0" class="data row18 col0" >21.67</td>
#       <td id="T_e672e_row18_col1" class="data row18 col1" >1526.00</td>
#     </tr>
#     <tr>
#       <th id="T_e672e_level0_row19" class="row_heading level0 row19" >multiple_lines</th>
#       <td id="T_e672e_row19_col0" class="data row19 col0" >9.68</td>
#       <td id="T_e672e_row19_col1" class="data row19 col1" >682.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Пропуски образовались при соединении таблиц заменим на 'No'

# %%
df = df.fillna('No')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   object
#  8   gender             7043 non-null   object
#  9   senior_citizen     7043 non-null   int64
#  10  partner            7043 non-null   object
#  11  dependents         7043 non-null   object
#  12  internet_service   7043 non-null   object
#  13  online_security    7043 non-null   object
#  14  online_backup      7043 non-null   object
#  15  device_protection  7043 non-null   object
#  16  tech_support       7043 non-null   object
#  17  streaming_tv       7043 non-null   object
#  18  streaming_movies   7043 non-null   object
#  19  multiple_lines     7043 non-null   object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# Преобрзуем в формат даты времени

# %%
df['begin_date'] = pd.to_datetime(df['begin_date'])

# %% [markdown]
# При предварительном исследовании нам попадались даты с днем равным 1 проверим, если так следовательно данные представлены с разбивкой по месяцам

# %%
df['begin_date'].dt.day.unique()
# Out:
# array([1], dtype=int64)

# %%
df['end_date'].unique()
# Out:
# array(['No', '2019-12-01 00:00:00', '2019-11-01 00:00:00',
#        '2019-10-01 00:00:00', '2020-01-01 00:00:00'], dtype=object)

# %% [markdown]
# Клиенты начали уходить с 2019-10-01. Странно что до этого за такой долгий срок работы из компании не ушел ни один клиент, а потом резко начали

# %% [markdown]
# Создадим нашу целевую переменную

# %%
df['target'] = np.where((df['end_date'] != 'No'), 1, 0)

# %%
df['end_date'] = pd.to_datetime(df['end_date'], errors ='coerce')
df['end_date'].max()
# Out:
# Timestamp('2020-01-01 00:00:00')

# %% [markdown]
# Максимальная дата растожения контракта отличается от даты выгрузки `2020-02-01`, поэтому можем заменить все `NaT` на нее. При исследовании данных будем учитывать данную замену

# %%
df['end_date'] = df['end_date'].fillna(pd.Timestamp('2020-02-01'))

# %% [markdown]
# Теперь добавим столбец с длительностью контракта до момента расторжения или если клиент не ушел на дату выгрузки

# %%
df['term'] = (df['end_date'].dt.to_period('M') - df['begin_date'].dt.to_period('M')).apply(lambda x: x.n)

# %%
df.head()
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month               Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year                No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month               Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year                No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges total_charges  gender  \
# 0           Electronic check            29.85         29.85  Female
# 1               Mailed check            56.95        1889.5    Male
# 2               Mailed check            53.85        108.15    Male
# 3  Bank transfer (automatic)            42.30       1840.75    Male
# 4           Electronic check            70.70        151.65  Female
#
#    senior_citizen  ... internet_service online_security online_backup  \
# 0               0  ...              DSL              No           Yes
# 1               0  ...              DSL             Yes            No
# 2               0  ...              DSL             Yes           Yes
# 3               0  ...              DSL             Yes            No
# 4               0  ...      Fiber optic              No            No
#
#   device_protection tech_support streaming_tv streaming_movies multiple_lines  \
# 0                No           No           No               No             No
# 1               Yes           No           No               No             No
# 2                No           No           No               No             No
# 3               Yes          Yes           No               No             No
# 4                No           No           No               No             No
#
#   target term
# 0      0    1
# 1      0   34
# 2      1    2
# 3      0   45
# 4      1    2
#
# [5 rows x 22 columns]

# %%
df.total_charges.sort_values().head(15)
# Out:
# 936
# 3826
# 4380
# 753
# 5218
# 3331
# 6754
# 6670
# 1340
# 488
# 1082
# 105      100.2
# 4459    100.25
# 1723    100.35
# 2124     100.4
# Name: total_charges, dtype: object

# %% [markdown]
# В столбце `total_charges` пропуски заполнены пробелами, проверим что это за клиенты

# %%
df.query('total_charges == " "')['begin_date'].unique()
# Out:
# array(['2020-02-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# Все клиенты пришли 2020-02-01 и не пользовались еще услугами, поэтому у них еще нет `total_charges`. И не известно уйдут они или останутся. Преобразуем столбец и удалим их

# %%
df['total_charges'] = pd.to_numeric(df['total_charges'], errors ='coerce').sort_values()
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7032 non-null   object
#  1   begin_date         7032 non-null   datetime64[ns]
#  2   end_date           7032 non-null   datetime64[ns]
#  3   type               7032 non-null   object
#  4   paperless_billing  7032 non-null   object
#  5   payment_method     7032 non-null   object
#  6   monthly_charges    7032 non-null   float64
#  7   total_charges      7032 non-null   float64
#  8   gender             7032 non-null   object
#  9   senior_citizen     7032 non-null   int64
#  10  partner            7032 non-null   object
#  11  dependents         7032 non-null   object
#  12  internet_service   7032 non-null   object
#  13  online_security    7032 non-null   object
#  14  online_backup      7032 non-null   object
#  15  device_protection  7032 non-null   object
#  16  tech_support       7032 non-null   object
#  17  streaming_tv       7032 non-null   object
#  18  streaming_movies   7032 non-null   object
#  19  multiple_lines     7032 non-null   object
#  20  target             7032 non-null   int32
#  21  term               7032 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int32(1), int64(2), object(15)
# memory usage: 1.2+ MB

# %% [markdown]
# Разделим ID на текстовую и числовую часть

# %%
df[['num_id', 'text_id']] = df['customer_id'].str.split('-', 1, expand= True)
df['num_id'] = df['num_id'].astype(int)

# %% [markdown]
# Добавим также столбец с разницей

# %%
df['monthly_charges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: monthly_charges, Length: 7032, dtype: float64

# %%
df['total_charges'] / df['term']
# Out:
# 0        29.850000
# 1        55.573529
# 2        54.075000
# 3        40.905556
# 4        75.825000
#            ...
# 7038     82.937500
# 7039    102.262500
# 7040     31.495455
# 7041     76.650000
# 7042    103.704545
# Length: 7032, dtype: float64

# %%
def reduce_increase(month, total, term):
    if (total/term) > month:
        return 1
    elif (total/term) < month:
        return -1
    else:
        return 0

# %%
df['reduce_increase_services'] = df.apply(lambda df: reduce_increase(
    df['monthly_charges'], 
    df['total_charges'], 
    df['term']), axis=1)

# %%
df.head()
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month               Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year                No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month               Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year                No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges  gender  \
# 0           Electronic check            29.85          29.85  Female
# 1               Mailed check            56.95        1889.50    Male
# 2               Mailed check            53.85         108.15    Male
# 3  Bank transfer (automatic)            42.30        1840.75    Male
# 4           Electronic check            70.70         151.65  Female
#
#    senior_citizen  ... device_protection tech_support streaming_tv  \
# 0               0  ...                No           No           No
# 1               0  ...               Yes           No           No
# 2               0  ...                No           No           No
# 3               0  ...               Yes          Yes           No
# 4               0  ...                No           No           No
#
#   streaming_movies multiple_lines target term num_id text_id  \
# 0               No             No      0    1   7590   VHVEG
# 1               No             No      0   34   5575   GNVDE
# 2               No             No      1    2   3668   QPYBK
# 3               No             No      0   45   7795   CFOCW
# 4               No             No      1    2   9237   HQITU
#
#   reduce_increase_services
# 0                        0
# 1                       -1
# 2                        1
# 3                       -1
# 4                        1
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Вывод:

# %%
interval  = ['monthly_charges', 'total_charges', 'senior_citizen', 'target', 'term', 'num_id', 'reduce_increase_services']

# %%
phik_overview = df.drop(['customer_id', 'begin_date', 'end_date', 'text_id'], axis=1).phik_matrix(interval_col)
# Out:
# interval columns not set, guessing: ['monthly_charges', 'total_charges', 'senior_citizen', 'target', 'term', 'num_id', 'reduce_increase_services']

# %%
plt.figure(figsize=(15,12))
plt.title(' ')
sns.heatmap(round(phik_overview, 2), 
            annot=True, 
            vmin=0, 
            vmax=1, 
            center= 0, 
            cmap= 'coolwarm', 
            square=True);

# %%
#TODO most popular set of services
#TODO return price of all service

# %%
dfs = df.drop(['begin_date', 'end_date', 'customer_id', 'text_id'], axis=1).copy()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.utils import shuffle # Миксер
from sklearn.utils.validation import check_is_fitted

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier

from catboost import CatBoostClassifier

# %%
X, y = dfs.drop(['target'], axis=1), df['target']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.25, 
    random_state=47,
    shuffle=True,
    stratify=df['target'])

print('Обучающая выборка:')
print('Доля от общего размера:', round(y_train.shape[0]/df.shape[0], 2))
print('Cтрок, столбцов:', X_train.shape)
print('Доля целевого признака:', round(y_train.mean(), 3))
print('- '*10)


print('Тестовая выборка:')
print('Доля от общего размера:', round(y_test.shape[0]/df.shape[0], 2))
print('Cтрок, столбцов:', X_test.shape)
print('Доля целевого признака:', round(y_test.mean(), 3))
print('-'*30)
# Out:
# Обучающая выборка:
# Доля от общего размера: 0.75
# Cтрок, столбцов: (5274, 20)
# Доля целевого признака: 0.266
# - - - - - - - - - -
# Тестовая выборка:
# Доля от общего размера: 0.25
# Cтрок, столбцов: (1758, 20)
# Доля целевого признака: 0.266
# ------------------------------

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
cat_pipe = Pipeline([('encoder', OneHotEncoder(handle_unknown='ignore'))])
num_pipe = Pipeline([('scaler', MinMaxScaler())])

preprocessor = ColumnTransformer([
    ('cat', cat_pipe, categorical),
    ('num', num_pipe, numerical)
])

pipe = Pipeline(
    [
        ('preprocessor', preprocessor),
        ("regressor", RFECV(
    estimator=RandomForestClassifier(random_state=42), 
    cv=5, 
    scoring='accuracy',
    verbose=3,
    step=5))
    ]
)



pipe.fit(X_train, y_train)
# Out:
# Fitting estimator with 38 features.
# Fitting estimator with 33 features.
# Fitting estimator with 28 features.
# Fitting estimator with 23 features.
# Fitting estimator with 18 features.
# Fitting estimator with 13 features.
# Fitting estimator with 8 features.
# Fitting estimator with 3 features.
# Fitting estimator with 38 features.
# Fitting estimator with 33 features.
# Fitting estimator with 28 features.
# Fitting estimator with 23 features.
# Fitting estimator with 18 features.
# Fitting estimator with 13 features.
# Fitting estimator with 8 features.
# Fitting estimator with 3 features.
# Fitting estimator with 38 features.
# Fitting estimator with 33 features.
# Fitting estimator with 28 features.
# Fitting estimator with 23 features.
# Fitting estimator with 18 features.
# Fitting estimator with 13 features.
# Fitting estimator with 8 features.
# Fitting estimator with 3 features.
# Fitting estimator with 38 features.
# Fitting estimator with 33 features.
# Fitting estimator with 28 features.
# Fitting estimator with 23 features.
# Fitting estimator with 18 features.
# Fitting estimator with 13 features.
# Fitting estimator with 8 features.
# Fitting estimator with 3 features.
# Fitting estimator with 38 features.
# Fitting estimator with 33 features.
# Fitting estimator with 28 features.
# Fitting estimator with 23 features.
# Fitting estimator with 18 features.
# Fitting estimator with 13 features.
# Fitting estimator with 8 features.
# Fitting estimator with 3 features.
# Fitting estimator with 38 features.
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['type', 'paperless_billing',
#                                                    'payment_method', 'gender',
#                                                    'partner', 'dependents',
#                                                    'internet_service',
#                                                    'online_security',
#                                                    'online_backup',
#                                                    'device_protection',
#                                                    'tech_support',
#                                                    'streaming_tv',
#                                                    'streaming_movies',
#                                                    'multiple_lines']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['monthly_charges',
#                                                    'total_charges',
#                                                    'senior_citizen', 'term',
#                                                    'num_id',
#                                                    'reduce_increase_services'])])),
#                 ('regressor',
#                  RFECV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                        scoring='accuracy', step=5, verbose=3))])

# %%
X_new = pipe.transform(X)
print("Num Features Before:", X.shape[1])
print("Num Features After:", X_new.shape[1])
# Out:
# Num Features Before: 20
# Num Features After: 20

# %%
features_kept = pd.DataFrame({'columns': X.columns,
                             'Kept': pipe.support_})
features_kept
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12480/2067955395.py in <module>
#       1 features_kept = pd.DataFrame({'columns': X.columns,
# ----> 2                              'Kept': pipe.support_})
#       3 features_kept
#
# AttributeError: 'Pipeline' object has no attribute 'support_'

# %%
categorical = list(X_train.select_dtypes('object').columns)
print(f"Категориальные признаки: {categorical}")

numerical = list(X_train.select_dtypes('number').columns)
print(f"Числовые признаки: {numerical}")
# Out:
# Категориальные признаки: ['type', 'paperless_billing', 'payment_method', 'gender', 'partner', 'dependents', 'internet_service', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies', 'multiple_lines']
# Числовые признаки: ['monthly_charges', 'total_charges', 'senior_citizen', 'term', 'num_id', 'reduce_increase_services']

# %%
cat_pipe = Pipeline([('encoder', OneHotEncoder(handle_unknown='ignore'))])
num_pipe = Pipeline([('scaler', MinMaxScaler())])

preprocessor = ColumnTransformer([
    ('cat', cat_pipe, categorical),
    ('num', num_pipe, numerical)
])

pipe = Pipeline(
    [
        ('preprocessor', preprocessor),
        ("regressor", KNeighborsClassifier())
    ]
)

param_grid = [
    {
        'regressor': [KNeighborsClassifier()],
        'regressor__n_neighbors': range(2,40,2),
        'regressor__leaf_size': range(10,100,2),
        'regressor__weights': ['uniform', 'distance'],
        'regressor__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']

    },
    # {
    #     'regressor': [RandomForestClassifier(random_state=RANDOM_STATE)],
    #     'regressor__max_depth': range(2,9,1),
    #     # 'regressor__n_estimators':range(1,201,10),
    #     # 'regressor__min_samples_split':range(2,52,5),
    #     # 'regressor__min_samples_leaf':range(2,52,5),
    #     # 'regressor__max_features': ['sqrt', 'log2']
    # },
    # {
    #     'regressor': [CatBoostClassifier(random_state=RANDOM_STATE, silent=True)],
    #     # 'regressor__max_iter': [1000],
    #     # 'regressor__class_weight': [None, 'balanced'],
    #     # 'regressor__solver' : ['lbfgs', 'liblinear']
    # }
]


grid = RandomizedSearchCV(pipe, param_grid, n_iter=250 ,cv=5, scoring = 'roc_auc', verbose=3)

# %%
# %%time
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=12, regressor__weights=uniform;, score=0.812 total time=   0.3s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=12, regressor__weights=uniform;, score=0.796 total time=   0.2s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=12, regressor__weights=uniform;, score=0.802 total time=   0.2s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=12, regressor__weights=uniform;, score=0.811 total time=   0.2s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=12, regressor__weights=uniform;, score=0.820 total time=   0.2s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.802 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.788 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.787 total time=   0.0s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.797 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.806 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=30, regressor__weights=uniform;, score=0.814 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=30, regressor__weights=uniform;, score=0.811 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=30, regressor__weights=uniform;, score=0.823 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=30, regressor__weights=uniform;, score=0.820 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=30, regressor__weights=uniform;, score=0.831 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=24, regressor__n_neighbors=12, regressor__weights=distance;, score=0.808 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=24, regressor__n_neighbors=12, regressor__weights=distance;, score=0.783 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=24, regressor__n_neighbors=12, regressor__weights=distance;, score=0.791 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=24, regressor__n_neighbors=12, regressor__weights=distance;, score=0.811 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=24, regressor__n_neighbors=12, regressor__weights=distance;, score=0.815 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=46, regressor__n_neighbors=6, regressor__weights=distance;, score=0.791 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=46, regressor__n_neighbors=6, regressor__weights=distance;, score=0.757 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=46, regressor__n_neighbors=6, regressor__weights=distance;, score=0.767 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=46, regressor__n_neighbors=6, regressor__weights=distance;, score=0.782 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=46, regressor__n_neighbors=6, regressor__weights=distance;, score=0.786 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=60, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.802 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=60, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.788 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=60, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.787 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=60, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.797 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=60, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.806 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=22, regressor__n_neighbors=10, regressor__weights=distance;, score=0.808 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=22, regressor__n_neighbors=10, regressor__weights=distance;, score=0.777 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=22, regressor__n_neighbors=10, regressor__weights=distance;, score=0.784 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=22, regressor__n_neighbors=10, regressor__weights=distance;, score=0.806 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=22, regressor__n_neighbors=10, regressor__weights=distance;, score=0.807 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=14, regressor__weights=distance;, score=0.808 total time=   0.2s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=14, regressor__weights=distance;, score=0.787 total time=   0.2s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=14, regressor__weights=distance;, score=0.796 total time=   0.3s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=14, regressor__weights=distance;, score=0.816 total time=   0.2s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=14, regressor__weights=distance;, score=0.817 total time=   0.2s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=84, regressor__n_neighbors=14, regressor__weights=uniform;, score=0.810 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=84, regressor__n_neighbors=14, regressor__weights=uniform;, score=0.800 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=84, regressor__n_neighbors=14, regressor__weights=uniform;, score=0.806 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=84, regressor__n_neighbors=14, regressor__weights=uniform;, score=0.814 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=84, regressor__n_neighbors=14, regressor__weights=uniform;, score=0.820 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=98, regressor__n_neighbors=12, regressor__weights=distance;, score=0.808 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=98, regressor__n_neighbors=12, regressor__weights=distance;, score=0.783 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=98, regressor__n_neighbors=12, regressor__weights=distance;, score=0.791 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=98, regressor__n_neighbors=12, regressor__weights=distance;, score=0.811 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=98, regressor__n_neighbors=12, regressor__weights=distance;, score=0.815 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=96, regressor__n_neighbors=36, regressor__weights=distance;, score=0.816 total time=   0.2s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=96, regressor__n_neighbors=36, regressor__weights=distance;, score=0.810 total time=   0.2s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=96, regressor__n_neighbors=36, regressor__weights=distance;, score=0.815 total time=   0.2s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=96, regressor__n_neighbors=36, regressor__weights=distance;, score=0.822 total time=   0.4s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=96, regressor__n_neighbors=36, regressor__weights=distance;, score=0.836 total time=   0.4s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=kd_tree, regressor__leaf_size=12, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.793 total time=   0.5s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=kd_tree, regressor__leaf_size=12, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.771 total time=   0.3s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=kd_tree, regressor__leaf_size=12, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.772 total time=   0.3s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=kd_tree, regressor__leaf_size=12, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.786 total time=   0.3s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=kd_tree, regressor__leaf_size=12, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.795 total time=   0.3s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=72, regressor__n_neighbors=2, regressor__weights=distance;, score=0.717 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=72, regressor__n_neighbors=2, regressor__weights=distance;, score=0.664 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=72, regressor__n_neighbors=2, regressor__weights=distance;, score=0.717 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=72, regressor__n_neighbors=2, regressor__weights=distance;, score=0.685 total time=   0.2s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=72, regressor__n_neighbors=2, regressor__weights=distance;, score=0.731 total time=   0.6s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=10, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.809 total time=   0.3s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=10, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.804 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=10, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.818 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=10, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.820 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=10, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.828 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=14, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.793 total time=   0.2s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=14, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.771 total time=   0.2s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=14, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.772 total time=   0.2s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=14, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.786 total time=   0.2s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=14, regressor__n_neighbors=6, regressor__weights=uniform;, score=0.795 total time=   0.2s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=18, regressor__weights=uniform;, score=0.809 total time=   0.0s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=18, regressor__weights=uniform;, score=0.802 total time=   0.0s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=18, regressor__weights=uniform;, score=0.818 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=18, regressor__weights=uniform;, score=0.815 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=72, regressor__n_neighbors=18, regressor__weights=uniform;, score=0.823 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=42, regressor__n_neighbors=32, regressor__weights=distance;, score=0.815 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=42, regressor__n_neighbors=32, regressor__weights=distance;, score=0.808 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=42, regressor__n_neighbors=32, regressor__weights=distance;, score=0.816 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=42, regressor__n_neighbors=32, regressor__weights=distance;, score=0.824 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=42, regressor__n_neighbors=32, regressor__weights=distance;, score=0.832 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.814 total time=   0.2s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.817 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.822 total time=   0.2s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.822 total time=   0.2s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=94, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.837 total time=   0.2s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size
total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=92, regressor__n_neighbors=16, regressor__weights=distance;, score=0.789 total time=   0.0s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=92, regressor__n_neighbors=16, regressor__weights=distance;, score=0.803 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=92, regressor__n_neighbors=16, regressor__weights=distance;, score=0.818 total time=   0.0s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=92, regressor__n_neighbors=16, regressor__weights=distance;, score=0.817 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=98, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.814 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=98, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.817 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=98, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.822 total time=   0.2s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=98, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.822 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=98, regressor__n_neighbors=34, regressor__weights=uniform;, score=0.837 total time=   0.2s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=52, regressor__n_neighbors=32, regressor__weights=distance;, score=0.815 total time=   0.2s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=52, regressor__n_neighbors=32, regressor__weights=distance;, score=0.808 total time=   0.2s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=52, regressor__n_neighbors=32, regressor__weights=distance;, score=0.816 total time=   0.2s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=52, regressor__n_neighbors=32, regressor__weights=distance;, score=0.824 total time=   0.2s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=52, regressor__n_neighbors=32, regressor__weights=distance;, score=0.832 total time=   0.2s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=24, regressor__weights=distance;, score=0.811 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=24, regressor__weights=distance;, score=0.797 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=24, regressor__weights=distance;, score=0.812 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=24, regressor__weights=distance;, score=0.820 total time=   0.1s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=auto, regressor__leaf_size=66, regressor__n_neighbors=24, regressor__weights=distance;, score=0.827 total time=   0.1s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=86, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.809 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=86, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.804 total time=   0.1s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=86, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.818 total time=   0.1s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=86, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.820 total time=   0.0s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=86, regressor__n_neighbors=20, regressor__weights=uniform;, score=0.828 total time=   0.0s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=64, regressor__n_neighbors=34, regressor__weights=distance;, score=0.815 total time=   0.2s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=64, regressor__n_neighbors=34, regressor__weights=distance;, score=0.808 total time=   0.2s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=64, regressor__n_neighbors=34, regressor__weights=distance;, score=0.815 total time=   0.2s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=64, regressor__n_neighbors=34, regressor__weights=distance;, score=0.825 total time=   0.2s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=64, regressor__n_neighbors=34, regressor__weights=distance;, score=0.834 total time=   0.2s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=70, regressor__n_neighbors=14, regressor__weights=distance;, score=0.808 total time=   0.1s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=70, regressor__n_neighbors=14, regressor__weights=distance;, score=0.787 total time=   0.0s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=70, regressor__n_neighbors=14, regressor__weights=distance;, score=0.796 total time=   0.0s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=70, regressor__n_neighbors=14, regressor__weights=distance;, score=0.816 total time=   0.0s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=brute, regressor__leaf_size=70, regressor__n_neighbors=14, regressor__weights=distance;, score=0.817 total time=   0.0s
# [CV 1/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.802 total time=   0.2s
# [CV 2/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.788 total time=   0.2s
# [CV 3/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.787 total time=   0.2s
# [CV 4/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.797 total time=   0.2s
# [CV 5/5] END regressor=KNeighborsClassifier(), regressor__algorithm=ball_tree, regressor__leaf_size=24, regressor__n_neighbors=8, regressor__weights=uniform;, score=0.806 total time=   0.2s
# Wall time: 5min
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('cat',
#                                                                                Pipeline(steps=[('encoder',
#                                                                                                 OneHotEncoder(handle_unknown='ignore'))]),
#                                                                                ['type',
#                                                                                 'paperless_billing',
#                                                                                 'payment_method',
#                                                                                 'gender',
#                                                                                 'partner',
#                                                                                 'dependents',
#                                                                                 'internet_service',
#                                                                                 'online_security',
#                                                                                 'online_backup',
#                                                                                 'device_protection',
#                                                                                 'tech_support',
#                                                                                 'streaming_...
#                                               KNeighborsClassifier())]),
#                    n_iter=250,
#                    param_distributions=[{'regressor': [KNeighborsClassifier(algorithm='kd_tree',
#                                                                             leaf_size=12,
#                                                                             n_neighbors=38)],
#                                          'regressor__algorithm': ['auto',
#                                                                   'ball_tree',
#                                                                   'kd_tree',
#                                                                   'brute'],
#                                          'regressor__leaf_size': range(10, 100, 2),
#                                          'regressor__n_neighbors': range(2, 40, 2),
#                                          'regressor__weights': ['uniform',
#                                                                 'distance']}],
#                    scoring='roc_auc', verbose=3)

# %%
result = pd.DataFrame(grid.cv_results_)

result.sort_values('mean_test_score', ascending=False)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 25       0.028984      0.003032         0.134523        0.013433
# 43       0.078355      0.001854         0.417362        0.032302
# 42       0.068361      0.003497         0.242462        0.010474
# 24       0.027185      0.002399         0.125528        0.005080
# 37       0.026527      0.000650         0.128436        0.004174
# 6        0.062897      0.001727         0.224299        0.004668
# 12       0.072941      0.007547         0.265348        0.035792
# 19       0.067762      0.003249         0.236465        0.006308
# 29       0.054768      0.005341         0.216477        0.018261
# 20       0.026785      0.000978         0.129526        0.008794
# 0        0.043394      0.010769         0.198000        0.047689
# 30       0.054568      0.001019         0.213679        0.005416
# 3        0.029058      0.003480         0.133678        0.010447
# 14       0.028384      0.002153         0.138720        0.012198
# 41       0.052587      0.005201         0.217331        0.024408
# 39       0.026558      0.000418         0.124017        0.005974
# 21       0.028984      0.002449         0.137920        0.019909
# 5        0.027294      0.001271         0.138330        0.010226
# 38       0.027218      0.002637         0.123501        0.004698
# 28       0.025786      0.000748         0.125128        0.006010
# 46       0.080155      0.003058         0.389977        0.029631
# 10       0.068875      0.001464         0.232910        0.008399
# 40       0.027737      0.002126         0.124516        0.003187
# 4        0.031896      0.004566         0.160816        0.012033
# 45       0.053769      0.004068         0.207482        0.018607
# 22       0.085950      0.007610         0.430624        0.136082
# 44       0.028584      0.002575         0.129126        0.009276
# 35       0.030327      0.005972         0.135201        0.010770
# 27       0.027385      0.001019         0.121456        0.007195
# 11       0.054041      0.001747         0.222955        0.025256
# 9        0.026670      0.000576         0.123781        0.005411
# 16       0.027185      0.001938         0.120131        0.003122
# 33       0.026709      0.000659         0.123996        0.009342
# 31       0.063163      0.004442         0.197057        0.015897
# 34       0.050773      0.003036         0.193425        0.006129
# 48       0.026186      0.000979         0.122330        0.004628
# 2        0.027136      0.000918         0.133300        0.010997
# 13       0.026586      0.001855         0.127326        0.011302
# 17       0.028385      0.003495         0.129524        0.024520
# 32       0.028015      0.002789         0.118344        0.003778
# 1        0.033888      0.006370         0.157086        0.033921
# 15       0.063363      0.003553         0.178499        0.002244
# 47       0.072357      0.001355         0.245460        0.018018
# 49       0.068561      0.003005         0.209281        0.009886
# 18       0.049971      0.002096         0.182097        0.003866
# 8        0.027509      0.000444         0.125789        0.006402
# 23       0.027784      0.003185         0.118132        0.006551
# 7        0.057615      0.001563         0.235143        0.050644
# 36       0.029736      0.001505         0.111451        0.003606
# 26       0.077755      0.002135         0.253655        0.009277
#
#    param_regressor__weights param_regressor__n_neighbors  \
# 25                  uniform                           36
# 43                  uniform                           36
# 42                  uniform                           36
# 24                  uniform                           34
# 37                  uniform                           32
# 6                  distance                           38
# 12                 distance                           36
# 19                 distance                           36
# 29                 distance                           34
# 20                  uniform                           28
# 0                   uniform                           28
# 30                  uniform                           26
# 3                   uniform                           26
# 14                  uniform                           26
# 41                  uniform                           24
# 39                  uniform                           24
# 21                  uniform                           22
# 5                  distance                           24
# 38                 distance                           24
# 28                 distance                           24
# 46                  uniform                           18
# 10                  uniform                           18
# 40                 distance                           22
# 4                  distance                           22
# 45                  uniform                           16
# 22                  uniform                           16
# 44                 distance                           20
# 35                 distance                           20
# 27                 distance                           20
# 11                 distance                           18
# 9                  distance                           18
# 16                 distance                           18
# 33                  uniform                           12
# 31                  uniform                           12
# 34                 distance                           16
# 48                 distance                           16
# 2                  distance                           14
# 13                 distance                           12
# 17                 distance                           12
# 32                  uniform                            8
# 1                   uniform                            8
# 15                  uniform                            6
# 47                 distance                            6
# 49                 distance                            6
# 18                 distance                            6
# 8                   uniform                            4
# 23                 distance                            4
# 7                  distance                            2
# 36                 distance                            2
# 26                 distance                            2
#
#    param_regressor__leaf_size param_regressor__algorithm  \
# 25                         30                       auto
# 43                         15                    kd_tree
# 42                         50                    kd_tree
# 24                         10                      brute
# 37                         40                      brute
# 6                          90                    kd_tree
# 12                         50                    kd_tree
# 19                         60                    kd_tree
# 29                         35                  ball_tree
# 20                         75                      brute
# 0                          85                      brute
# 30                         25                  ball_tree
# 3                          55                      brute
# 14                         25                      brute
# 41                         90                  ball_tree
# 39                         35                       auto
# 21                         55                       auto
# 5                          90                       auto
# 38                         35                       auto
# 28                         60                      brute
# 46                         15                    kd_tree
# 10                         35                    kd_tree
# 40                         40                       auto
# 4                          30                      brute
# 45                         40                  ball_tree
# 22                         30                    kd_tree
# 44                         25                       auto
# 35                         55                      brute
# 27                         95                       auto
# 11                         50                  ball_tree
# 9                          20                      brute
# 16                         40                       auto
# 33                         35                       auto
# 31                         85                    kd_tree
# 34                         90                  ball_tree
# 48                         25                       auto
# 2                          50                      brute
# 13                         85                       auto
# 17                         95                       auto
# 32                         35                       auto
# 1                          75                      brute
# 15                         90                    kd_tree
# 47                         25                    kd_tree
# 49                         45                    kd_tree
# 18                         70                  ball_tree
# 8                          45                      brute
# 23                         80                       auto
# 7                          30                  ball_tree
# 36                         75                      brute
# 26                         15                    kd_tree
#
#                          param_regressor  \
# 25  KNeighborsClassifier(n_neighbors=36)
# 43  KNeighborsClassifier(n_neighbors=36)
# 42  KNeighborsClassifier(n_neighbors=36)
# 24  KNeighborsClassifier(n_neighbors=36)
# 37  KNeighborsClassifier(n_neighbors=36)
# 6   KNeighborsClassifier(n_neighbors=36)
# 12  KNeighborsClassifier(n_neighbors=36)
# 19  KNeighborsClassifier(n_neighbors=36)
# 29  KNeighborsClassifier(n_neighbors=36)
# 20  KNeighborsClassifier(n_neighbors=36)
# 0   KNeighborsClassifier(n_neighbors=36)
# 30  KNeighborsClassifier(n_neighbors=36)
# 3   KNeighborsClassifier(n_neighbors=36)
# 14  KNeighborsClassifier(n_neighbors=36)
# 41  KNeighborsClassifier(n_neighbors=36)
# 39  KNeighborsClassifier(n_neighbors=36)
# 21  KNeighborsClassifier(n_neighbors=36)
# 5   KNeighborsClassifier(n_neighbors=36)
# 38  KNeighborsClassifier(n_neighbors=36)
# 28  KNeighborsClassifier(n_neighbors=36)
# 46  KNeighborsClassifier(n_neighbors=36)
# 10  KNeighborsClassifier(n_neighbors=36)
# 40  KNeighborsClassifier(n_neighbors=36)
# 4   KNeighborsClassifier(n_neighbors=36)
# 45  KNeighborsClassifier(n_neighbors=36)
# 22  KNeighborsClassifier(n_neighbors=36)
# 44  KNeighborsClassifier(n_neighbors=36)
# 35  KNeighborsClassifier(n_neighbors=36)
# 27  KNeighborsClassifier(n_neighbors=36)
# 11  KNeighborsClassifier(n_neighbors=36)
# 9   KNeighborsClassifier(n_neighbors=36)
# 16  KNeighborsClassifier(n_neighbors=36)
# 33  KNeighborsClassifier(n_neighbors=36)
# 31  KNeighborsClassifier(n_neighbors=36)
# 34  KNeighborsClassifier(n_neighbors=36)
# 48  KNeighborsClassifier(n_neighbors=36)
# 2   KNeighborsClassifier(n_neighbors=36)
# 13  KNeighborsClassifier(n_neighbors=36)
# 17  KNeighborsClassifier(n_neighbors=36)
# 32  KNeighborsClassifier(n_neighbors=36)
# 1   KNeighborsClassifier(n_neighbors=36)
# 15  KNeighborsClassifier(n_neighbors=36)
# 47  KNeighborsClassifier(n_neighbors=36)
# 49  KNeighborsClassifier(n_neighbors=36)
# 18  KNeighborsClassifier(n_neighbors=36)
# 8   KNeighborsClassifier(n_neighbors=36)
# 23  KNeighborsClassifier(n_neighbors=36)
# 7   KNeighborsClassifier(n_neighbors=36)
# 36  KNeighborsClassifier(n_neighbors=36)
# 26  KNeighborsClassifier(n_neighbors=36)
#
#                                                params  split0_test_score  \
# 25  {'regressor__weights': 'uniform', 'regressor__...           0.815747
# 43  {'regressor__weights': 'uniform', 'regressor__...           0.815747
# 42  {'regressor__weights': 'uniform', 'regressor__...           0.815747
# 24  {'regressor__weights': 'uniform', 'regressor__...           0.814166
# 37  {'regressor__weights': 'uniform', 'regressor__...           0.814544
# 6   {'regressor__weights': 'distance', 'regressor_...           0.817336
# 12  {'regressor__weights': 'distance', 'regressor_...           0.816452
# 19  {'regressor__weights': 'distance', 'regressor_...           0.816452
# 29  {'regressor__weights': 'distance', 'regressor_...           0.815143
# 20  {'regressor__weights': 'uniform', 'regressor__...           0.814094
# 0   {'regressor__weights': 'uniform', 'regressor__...           0.814094
# 30  {'regressor__weights': 'uniform', 'regressor__...           0.813518
# 3   {'regressor__weights': 'uniform', 'regressor__...           0.813518
# 14  {'regressor__weights': 'uniform', 'regressor__...           0.813518
# 41  {'regressor__weights': 'uniform', 'regressor__...           0.811643
# 39  {'regressor__weights': 'uniform', 'regressor__...           0.811643
# 21  {'regressor__weights': 'uniform', 'regressor__...           0.812601
# 5   {'regressor__weights': 'distance', 'regressor_...           0.811401
# 38  {'regressor__weights': 'distance', 'regressor_...           0.811401
# 28  {'regressor__weights': 'distance', 'regressor_...           0.811401
# 46  {'regressor__weights': 'uniform', 'regressor__...           0.809076
# 10  {'regressor__weights': 'uniform', 'regressor__...           0.809076
# 40  {'regressor__weights': 'distance', 'regressor_...           0.811959
# 4   {'regressor__weights': 'distance', 'regressor_...           0.811959
# 45  {'regressor__weights': 'uniform', 'regressor__...           0.808309
# 22  {'regressor__weights': 'uniform', 'regressor__...           0.808309
# 44  {'regressor__weights': 'distance', 'regressor_...           0.808945
# 35  {'regressor__weights': 'distance', 'regressor_...           0.808945
# 27  {'regressor__weights': 'distance', 'regressor_...           0.808945
# 11  {'regressor__weights': 'distance', 'regressor_...           0.808166
# 9   {'regressor__weights': 'distance', 'regressor_...           0.808166
# 16  {'regressor__weights': 'distance', 'regressor_...           0.808166
# 33  {'regressor__weights': 'uniform', 'regressor__...           0.811590
# 31  {'regressor__weights': 'uniform', 'regressor__...           0.811590
# 34  {'regressor__weights': 'distance', 'regressor_...           0.807207
# 48  {'regressor__weights': 'distance', 'regressor_...           0.807207
# 2   {'regressor__weights': 'distance', 'regressor_...           0.807737
# 13  {'regressor__weights': 'distance', 'regressor_...           0.808233
# 17  {'regressor__weights': 'distance', 'regressor_...           0.808233
# 32  {'regressor__weights': 'uniform', 'regressor__...           0.801786
# 1   {'regressor__weights': 'uniform', 'regressor__...           0.801786
# 15  {'regressor__weights': 'uniform', 'regressor__...           0.792991
# 47  {'regressor__weights': 'distance', 'regressor_...           0.790970
# 49  {'regressor__weights': 'distance', 'regressor_...           0.790970
# 18  {'regressor__weights': 'distance', 'regressor_...           0.790970
# 8   {'regressor__weights': 'uniform', 'regressor__...           0.764779
# 23  {'regressor__weights': 'distance', 'regressor_...           0.763878
# 7   {'regressor__weights': 'distance', 'regressor_...           0.717479
# 36  {'regressor__weights': 'distance', 'regressor_...           0.717479
# 26  {'regressor__weights': 'distance', 'regressor_...           0.717479
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 25           0.818415           0.822823           0.819620
# 43           0.818415           0.822823           0.819620
# 42           0.818415           0.822823           0.819620
# 24           0.817399           0.822073           0.822246
# 37           0.816772           0.823717           0.821505
# 6            0.811041           0.816041           0.822974
# 12           0.809763           0.815264           0.822165
# 19           0.809763           0.815264           0.822165
# 29           0.808415           0.814641           0.824751
# 20           0.809645           0.821639           0.820533
# 0            0.809645           0.821639           0.820533
# 30           0.808394           0.822462           0.819625
# 3            0.808394           0.822462           0.819625
# 14           0.808394           0.822462           0.819625
# 41           0.805781           0.822177           0.818110
# 39           0.805781           0.822177           0.818110
# 21           0.804366           0.821574           0.818312
# 5            0.797479           0.812018           0.819857
# 38           0.797479           0.812018           0.819857
# 28           0.797479           0.812018           0.819857
# 46           0.801546           0.817549           0.815413
# 10           0.801546           0.817549           0.815413
# 40           0.795558           0.811990           0.819457
# 4            0.795558           0.811990           0.819457
# 45           0.800171           0.814905           0.815949
